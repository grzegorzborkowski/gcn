# %%
import csv
import tqdm
import copy
import nltk
nltk.download('stopwords')
import collections
from operator import itemgetter
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/grzegorz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import csv


def read_articles():
    articles = []
    with open('DBLP-citation-Jan8.txt') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='#')
        for row in csv_reader:
            if len(row) >= 2:
                data = row[1]
                if len(data)<2:
                    continue
                elif data[:1] == '*':
                    article = {}
                    article['quoted'] = []
                    article['title'] = data[1:]
                elif data[:1] == '@':
                    article['authors'] = data[1:]
                elif data[:1] == 't':
                    article['date'] = data[1:]
                elif data[:1] == 'c':
                    article['source'] = data[1:]
                elif data[:5] == 'index':
                    article['index'] = data[5:]
                    articles.append(article)
                elif data[:1] == '%':
                    if 'quoted' in article:
                        article['quoted'].append(data[1:])
                    else:
                        article['quoted'].append(data[1:])
                elif data[:1] == '!':
                    article['abstract'] = data[1:]
                else:
                    continue
    return articles

# %%
articles = read_articles()

# %%
def filter_articles_without_abstract(articles):
    return [article for article in articles if 'abstract' in article and 'authors' in article]

# %%
from nltk.corpus import stopwords
def tokenize_and_remove_step_words_from_abstract(articles):
    tokenizer = nltk.tokenize.SpaceTokenizer()
    stop_words_set = set(stopwords.words('english'))
    articles_copy = copy.deepcopy(articles)
    for article in tqdm.tqdm(articles_copy):
        try:
            article['abstract'] = tokenizer.tokenize(article['abstract'])
            article['abstract'] = [word for word in article['abstract'] if word not in stop_words_set]
        except AttributeError:
            pass
    return articles_copy

# %%
articles_with_abstract = filter_articles_without_abstract(articles)

# %%
articles_tokenized = tokenize_and_remove_step_words_from_abstract(articles_with_abstract)
# Out:
# 100%|██████████| 529247/529247 [00:11<00:00, 46957.77it/s]

# %%
articles_tokenized[:10]
# Out:
# [{'quoted': ['165'],
#   'title': 'Spatial Data Structures.',
#   'authors': 'Hanan Samet',
#   'date': '1995',
#   'source': 'Modern Database Systems',
#   'index': '25',
#   'abstract': ['An',
#    'overview',
#    'presented',
#    'use',
#    'spatial',
#    'data',
#    'structures',
#    'spatial',
#    'databases.',
#    'The',
#    'focus',
#    'hierarchical',
#    'data',
#    'structures,',
#    'including',
#    'number',
#    'variants',
#    'quadtrees,',
#    'sort',
#    'data',
#    'respect',
#    'space',
#    'occupied',
#    'it.',
#    'Such',
#    'techniques',
#    'known',
#    'spatial',
#    'indexing',
#    'methods.',
#    'Hierarchical',
#    'data',
#    'structures',
#    'based',
#    'principle',
#    'recursive',
#    'decomposition.',
#    'They',
#    'attractive',
#    'compact',
#    'depending',
#    'nature',
#    'data',
#    'save',
#    'space',
#    'well',
#    'time',
#    'also',
#    'facilitate',
#    'operations',
#    'search.',
#    'Examples',
#    'given',
#    'use',
#    'data',
#    'structures',
#    'representation',
#    'different',
#    'data',
#    'types',
#    'regions,',
#    'points,',
#    'rectangles,',
#    'lines,',
#    'volumes.']},
#  {'quoted': [],
#   'title': 'Specifying Systems, The TLA+ Language and Tools for Hardware and Software Engineers',
#   'authors': 'Leslie Lamport',
#   'date': '2002',
#   'index': '72',
#   'abstract': ['From',
#    'Book:',
#    'This',
#    'book',
#    'teach',
#    'write',
#    'specifications',
#    'computer',
#    'systems,',
#    'using',
#    'language',
#    'TLA+.',
#    "It's",
#    'rather',
#    'long,',
#    'people',
#    'read',
#    'Part',
#    'I,',
#    'comprises',
#    'first',
#    '83',
#    'pages.',
#    'That',
#    'part',
#    'contains',
#    'engineers',
#    'need',
#    'know',
#    'writing',
#    'specifications;',
#    'assumes',
#    'basic',
#    'background',
#    'computing',
#    'knowledge',
#    'mathematics',
#    'expected',
#    'undergraduate',
#    'studying',
#    'engineering',
#    'computer',
#    'science.',
#    'Part',
#    'II',
#    'contains',
#    'advanced',
#    'material',
#    'sophisticated',
#    'readers.',
#    'The',
#    'remainder',
#    'book',
#    'reference',
#    'manual\x97Part',
#    'III',
#    'TLA+',
#    'tools',
#    'Part',
#    'IV',
#    'language',
#    'itself.',
#    'The',
#    'TLA',
#    'World',
#    'Wide',
#    'Web',
#    'page',
#    'contains',
#    'material',
#    'accompany',
#    'book,',
#    'including',
#    'TLA+',
#    'tools,',
#    'exercises,',
#    'references',
#    'literature,',
#    'list',
#    'corrections.',
#    'There',
#    'link',
#    'TLA',
#    'Web',
#    'page',
#    'http://lamport.org.What',
#    'Is',
#    'Specification?Writing',
#    "nature's",
#    'way',
#    'letting',
#    'know',
#    'sloppy',
#    'thinking',
#    'is.-GuindonA',
#    'specification',
#    'written',
#    'description',
#    'system',
#    'supposed',
#    'do.',
#    'Specifying',
#    'system',
#    'helps',
#    'us',
#    'understand',
#    'it.',
#    "It's",
#    'good',
#    'idea',
#    'understand',
#    'system',
#    'building',
#    'it,',
#    'good',
#    'idea',
#    'write',
#    'specification',
#    'system',
#    'implementing',
#    'it.This',
#    'book',
#    'specifying',
#    'behavioral',
#    'properties',
#    'system\x97also',
#    'called',
#    'functional',
#    'logical',
#    'properties.',
#    'These',
#    'properties',
#    'specify',
#    'system',
#    'supposed',
#    'do.',
#    'There',
#    'important',
#    'kinds',
#    'properties',
#    'consider,',
#    'including',
#    'performance',
#    'properties.',
#    'Worst-case',
#    'performance',
#    'often',
#    'expressed',
#    'behavioral',
#    'property\x97forexample,',
#    'Chapter',
#    '9',
#    'explains',
#    'specify',
#    'system',
#    'must',
#    'react',
#    'within',
#    'certain',
#    'length',
#    'time.',
#    'However,',
#    'specifying',
#    'average',
#    'performance',
#    'beyond',
#    'scope',
#    'methods',
#    'described',
#    'here.Our',
#    'basic',
#    'tool',
#    'writing',
#    'specifications',
#    'mathematics.',
#    'Mathematics',
#    "nature's",
#    'way',
#    'letting',
#    'know',
#    'sloppy',
#    'writing',
#    'is.',
#    "It's",
#    'hard',
#    'precise',
#    'imprecise',
#    'language',
#    'like',
#    'English',
#    'Chinese.',
#    'In',
#    'engineering,',
#    'imprecision',
#    'lead',
#    'errors.',
#    'To',
#    'avoid',
#    'errors,',
#    'science',
#    'engineering',
#    'adopted',
#    'mathematics',
#    'language.The',
#    'mathematics',
#    'use',
#    'formal',
#    'math',
#    'grown',
#    'with.',
#    'Formal',
#    'mathematics',
#    "nature's",
#    'way',
#    'letting',
#    'know',
#    'sloppy',
#    'mathematics',
#    'is.',
#    'The',
#    'mathematics',
#    'written',
#    'mathematicians',
#    'scientists',
#    'really',
#    'precise.',
#    "It's",
#    'precise',
#    'small,',
#    'imprecise',
#    'large.',
#    'Each',
#    'equation',
#    'precise',
#    'assertion,',
#    'read',
#    'accompanying',
#    'words',
#    'understand',
#    'equations',
#    'relate',
#    'one',
#    'another',
#    'exactly',
#    'theorems',
#    'mean.',
#    'Logicians',
#    'developed',
#    'ways',
#    'eliminating',
#    'words',
#    'making',
#    'mathematics',
#    'completely',
#    'formal,',
#    'hence',
#    'completely',
#    'precise.Most',
#    'mathematicians',
#    'scientists',
#    'think',
#    'formal',
#    'mathematics,',
#    'without',
#    'words,',
#    'long',
#    'tiresome.',
#    "They're",
#    'wrong.',
#    'Ordinary',
#    'mathematics',
#    'expressed',
#    'compactly',
#    'precise,',
#    'completely',
#    'formal',
#    'language.',
#    'It',
#    'takes',
#    'two',
#    'dozen',
#    'lines',
#    'define',
#    'solution',
#    'arbitrary',
#    'differential',
#    'equation',
#    'Differential',
#    'Equations',
#    'module',
#    'Chapter',
#    '11.',
#    'But',
#    'specifications',
#    'need',
#    'sophisticated',
#    'mathematics.',
#    'Most',
#    'require',
#    'simple',
#    'application',
#    'standard',
#    'mathematical',
#    'concepts.Why',
#    'TLA+?We',
#    'specify',
#    'system',
#    'describing',
#    'allowed',
#    'behaviors\x97what',
#    'may',
#    'course',
#    'execution.',
#    'In',
#    '1977,',
#    'Amir',
#    'Pnueli',
#    'introduced',
#    'use',
#    'temporal',
#    'logic',
#    'describing',
#    'system',
#    'behaviors.',
#    'In',
#    'principle,',
#    'system',
#    'could',
#    'described',
#    'single',
#    'temporal',
#    'logic',
#    'formula.',
#    'In',
#    'practice,',
#    "couldn't.",
#    "Pnueli's",
#    'temporal',
#    'logic',
#    'ideal',
#    'describing',
#    'properties',
#    'systems,',
#    'awkward',
#    'others.',
#    'So,',
#    'usually',
#    'combined',
#    'traditional',
#    'way',
#    'describing',
#    'systems.In',
#    'late',
#    '1980s,',
#    'I',
#    'invented',
#    'TLA,',
#    'Temporal',
#    'Logic',
#    'Actions\x97a',
#    'simple',
#    'variant',
#    "Pnueli's",
#    'original',
#    'logic.',
#    'TLA',
#    'makes',
#    'practical',
#    'describe',
#    'system',
#    'single',
#    'formula.',
#    'Most',
#    'TLA',
#    'specification',
#    'consists',
#    'ordinary,',
#    'nontemporal',
#    'mathematics.',
#    'Temporal',
#    'logic',
#    'plays',
#    'significant',
#    'role',
#    'describing',
#    'properties',
#    'good',
#    'describing.',
#    'TLA',
#    'also',
#    'provides',
#    'nice',
#    'way',
#    'formalize',
#    'style',
#    'reasoning',
#    'systems',
#    'proved',
#    'effective',
#    'practice\x97a',
#    'style',
#    'known',
#    'assertional',
#    'reasoning.',
#    'However,',
#    'book',
#    'specification;',
#    'says',
#    'almost',
#    'nothing',
#    'proofs.Temporal',
#    'logic',
#    'assumes',
#    'underlying',
#    'logic',
#    'expressing',
#    'ordinary',
#    'mathematics.',
#    'There',
#    'many',
#    'ways',
#    'formalize',
#    'ordinary',
#    'math.',
#    'Most',
#    'computer',
#    'scientists',
#    'prefer',
#    'one',
#    'resembles',
#    'favorite',
#    'programming',
#    'language.',
#    'I',
#    'chose',
#    'instead',
#    'one',
#    'mathematicians',
#    'prefer\x97the',
#    'one',
#    'logicians',
#    'call',
#    'first-order',
#    'logic',
#    'set',
#    'theory.TLA',
#    'provides',
#    'mathematical',
#    'foundation',
#    'describing',
#    'systems.',
#    'To',
#    'write',
#    'specifications,',
#    'need',
#    'complete',
#    'language',
#    'built',
#    'atop',
#    'foundation.',
#    'I',
#    'initially',
#    'thought',
#    'language',
#    'sort',
#    'abstract',
#    'programming',
#    'language',
#    'whose',
#    'semantics',
#    'would',
#    'based',
#    'TLA.',
#    'I',
#    'know',
#    'kind',
#    'programming',
#    'language',
#    'constructs',
#    'would',
#    'best,',
#    'I',
#    'decided',
#    'start',
#    'writing',
#    'specifications',
#    'directly',
#    'TLA.',
#    'I',
#    'intended',
#    'introduce',
#    'programming',
#    'constructs',
#    'I',
#    'needed',
#    'them.',
#    'To',
#    'surprise,',
#    'I',
#    'discovered',
#    'I',
#    'need',
#    'them.',
#    'What',
#    'I',
#    'needed',
#    'robust',
#    'language',
#    'writing',
#    'mathematics.Although',
#    'mathematicians',
#    'developed',
#    'science',
#    'writing',
#    'formulas,',
#    'turned',
#    'science',
#    'engineering',
#    'discipline.',
#    'They',
#    'developed',
#    'notations',
#    'mathematics',
#    'small,',
#    'mathematics',
#    'large.',
#    'The',
#    'specification',
#    'real',
#    'system',
#    'dozens',
#    'even',
#    'hundreds',
#    'pages',
#    'long.',
#    'Mathematicians',
#    'know',
#    'write',
#    '20-line',
#    'formulas,',
#    '20-page',
#    'formulas.',
#    'So,',
#    'I',
#    'introduce',
#    'notations',
#    'writing',
#    'long',
#    'formulas.',
#    'What',
#    'I',
#    'took',
#    'programming',
#    'languages',
#    'ideas',
#    'modularizing',
#    'large',
#    'specifications.The',
#    'language',
#    'I',
#    'came',
#    'called',
#    'TLA+.',
#    'I',
#    'refined',
#    'TLA+',
#    'course',
#    'writing',
#    'specifications',
#    'disparate',
#    'systems.',
#    'But',
#    'changed',
#    'little',
#    'last',
#    'years.',
#    'I',
#    'found',
#    'TLA+',
#    'quite',
#    'good',
#    'specifying',
#    'wide',
#    'class',
#    'systems\x97from',
#    'program',
#    'interfaces',
#    '(APIs)',
#    'distributed',
#    'systems.',
#    'It',
#    'used',
#    'write',
#    'precise,',
#    'formal',
#    'description',
#    'almost',
#    'sort',
#    'discrete',
#    'system.',
#    "It's",
#    'especially',
#    'well',
#    'suited',
#    'describing',
#    'asynchronous',
#    'systems\x97that',
#    'is,',
#    'systems',
#    'components',
#    'operate',
#    'strict',
#    'lock-step.About',
#    'This',
#    'BookPart',
#    'I,',
#    'consisting',
#    'Chapters',
#    '1',
#    '7,',
#    'core',
#    'book',
#    'meant',
#    'read',
#    'beginning',
#    'end.',
#    'It',
#    'explains',
#    'specify',
#    'class',
#    'properties',
#    'known',
#    'safety',
#    'properties.',
#    'These',
#    'properties,',
#    'specified',
#    'almost',
#    'temporal',
#    'logic,',
#    'engineers',
#    'need',
#    'know',
#    'about.',
#    'After',
#    'reading',
#    'Part',
#    'I,',
#    'read',
#    'much',
#    'Part',
#    'II',
#    'like.',
#    'Each',
#    'chapters',
#    'independent',
#    'others.',
#    'Temporal',
#    'logic',
#    'comes',
#    'fore',
#    'Chapter',
#    '8,',
#    'used',
#    'specify',
#    'additional',
#    'class',
#    'properties',
#    'known',
#    'liveness',
#    'properties.',
#    'Chapter',
#    '9',
#    'describes',
#    'specify',
#    'real-time',
#    'properties,',
#    'Chapter',
#    '10',
#    'describes',
#    'write',
#    'specifications',
#    'compositions.',
#    'Chapter',
#    '11',
#    'contains',
#    'advanced',
#    'examples.',
#    'The',
#    'three',
#    'chapters',
#    'Part',
#    'III',
#    'serve',
#    'reference',
#    'manual',
#    'three',
#    'TLA+',
#    'tools:',
#    'Syntactic',
#    'Analyzer,',
#    'TLATEX',
#    'typesetting',
#    'program,',
#    'TLC',
#    'model',
#    'checker.',
#    'If',
#    'want',
#    'use',
#    'TLA+,',
#    'probably',
#    'want',
#    'use',
#    'tools.',
#    'They',
#    'available',
#    'TLA',
#    'Web',
#    'page.',
#    'TLC',
#    'sophisticated',
#    'them.',
#    'The',
#    'examples',
#    'Web',
#    'get',
#    'started',
#    'using',
#    'it,',
#    'read',
#    'Chapter',
#    '14',
#    'learn',
#    'use',
#    'TLC',
#    'effectively.Part',
#    'IV',
#    'reference',
#    'manual',
#    'TLA+',
#    'language.',
#    'Part',
#    'I',
#    'provides',
#    'good',
#    'enough',
#    'working',
#    'knowledge',
#    'language',
#    'purposes.',
#    'You',
#    'need',
#    'look',
#    'Part',
#    'IV',
#    'questions',
#    'fine',
#    'points',
#    'syntax',
#    'semantics.',
#    'Chapter',
#    '15',
#    'gives',
#    'syntax',
#    'TLA+.',
#    'Chapter',
#    '16',
#    'describes',
#    'precise',
#    'meanings',
#    'general',
#    'forms',
#    'built-in',
#    'operators',
#    'TLA+;',
#    'Chapter',
#    '17',
#    'describes',
#    'precise',
#    'meaning',
#    'higher-level',
#    'TLA+',
#    'constructs',
#    'definitions.',
#    'Together,',
#    'two',
#    'chapters',
#    'specify',
#    'semantics',
#    'language.',
#    'Chapter',
#    '18',
#    'describes',
#    'standard',
#    'modules\x97except',
#    'module',
#    'RealTime,',
#    'described',
#    'Chapter',
#    '9,',
#    'module',
#    'TLC,',
#    'described',
#    'Chapter',
#    '14.',
#    'You',
#    'might',
#    'want',
#    'look',
#    'chapter',
#    'curious',
#    'standard',
#    'elementary',
#    'mathematics',
#    'formalized',
#    'TLA+.Part',
#    'IV',
#    'something',
#    'may',
#    'want',
#    'refer',
#    'often:',
#    'mini-manual',
#    'compactly',
#    'presents',
#    'lots',
#    'useful',
#    'information.',
#    'Pages',
#    '268-273',
#    'list',
#    'TLA+',
#    'operators,',
#    'user-definable',
#    'symbols,',
#    'precedence',
#    'operators,',
#    'operators',
#    'defined',
#    'standard',
#    'modules,',
#    'ASCII',
#    'representation',
#    'symbols.']},
#  {'quoted': [],
#   'title': 'Algorithms',
#   'authors': 'Robert Sedgewick',
#   'date': '1983',
#   'index': '78',
#   'abstract': ['This',
#    'presentation',
#    'tutorial',
#    'AutoView,',
#    'AutoMod',
#    'extension',
#    'package',
#    'recreates',
#    'model',
#    'animation',
#    'according',
#    'user-defined',
#    'script.',
#    'AutoView',
#    'allows',
#    'users',
#    'restart',
#    'animation',
#    'move',
#    'back',
#    'forth',
#    'time',
#    '3-D',
#    'space.',
#    'Animation',
#    'created',
#    'using',
#    'text',
#    'files',
#    'generated',
#    'AutoMod',
#    'simulation',
#    'model.',
#    'By',
#    'creating',
#    'user-defined',
#    'camera',
#    'description',
#    'file,',
#    'animation',
#    'take',
#    'place',
#    'allows',
#    'panning',
#    'one',
#    'view',
#    'another,',
#    'well',
#    'attaching',
#    'camera',
#    'simulated',
#    'load',
#    'vehicle',
#    'traveling',
#    'entity',
#    'portions',
#    'animation.',
#    'The',
#    'animation',
#    'provided',
#    'enhanced',
#    'response',
#    'time',
#    'logical',
#    'statistical',
#    'processes',
#    'AutoMod',
#    '(which',
#    'slow',
#    'animation).',
#    'This',
#    'tutorial',
#    'demonstrates',
#    'several',
#    'animation',
#    'scripts',
#    'previously',
#    'constructed',
#    'AutoView,',
#    'discusses',
#    'creation',
#    'AutoView',
#    'files',
#    'AutoMod,',
#    'describes',
#    'development',
#    'camera',
#    'description',
#    'file.']},
#  {'quoted': [],
#   'title': 'Modern Information Retrieval',
#   'authors': 'Ricardo A. Baeza-Yates,Berthier A. Ribeiro-Neto',
#   'date': '1999',
#   'index': '85',
#   'abstract': [':This',
#    'rigorous',
#    'complete',
#    'textbook',
#    'first',
#    'course',
#    'information',
#    'retrieval',
#    'computer',
#    'science',
#    '(as',
#    'opposed',
#    'user-centred)',
#    'perspective.',
#    'The',
#    'advent',
#    'Internet',
#    'enormous',
#    'increase',
#    'volume',
#    'electronically',
#    'stored',
#    'information',
#    'generally',
#    'led',
#    'substantial',
#    'work',
#    'IR',
#    'computer',
#    'science',
#    'perspective',
#    '-',
#    'book',
#    'provides',
#    'up-to-date',
#    'student',
#    'oriented',
#    'treatment',
#    'subject.']},
#  {'quoted': [],
#   'title': 'Intelligent Database Systems',
#   'authors': 'Elisa Bertino,Barbara Catania,Gian Piero Zarri',
#   'date': '2001',
#   'index': '89',
#   'abstract': [':a',
#    'valuable',
#    'resource',
#    'anyone',
#    'working',
#    'intelligent',
#    'database',
#    'systems.',
#    'Good',
#    'background',
#    'coverage',
#    'field',
#    'databases',
#    'AI',
#    'provided',
#    'first',
#    'part',
#    'book,',
#    'later',
#    'excellent',
#    'analytical',
#    'discussions',
#    'relevant',
#    'projects.',
#    'The',
#    'authors',
#    'adopt',
#    'readable',
#    'style',
#    'enables',
#    'complex',
#    'topic',
#    'become',
#    'much',
#    'accessible."',
#    '-',
#    'Jenny',
#    'Carter,',
#    'Department',
#    'Computer',
#    'Science,',
#    'De',
#    'Montfort',
#    'University',
#    'This',
#    'book',
#    'provides',
#    'state',
#    'art',
#    'guide',
#    'new',
#    'developments',
#    'expert',
#    'database',
#    'systems,',
#    'unique',
#    'perspective',
#    'database',
#    'AI',
#    'areas.',
#    'It',
#    'gives',
#    'complete',
#    'detailed',
#    'coverage',
#    'latest',
#    'research',
#    'practice,',
#    'including',
#    'need-to-know',
#    'technical',
#    'theoretical',
#    'approaches',
#    'area.',
#    'Drawing',
#    'extensive',
#    'experience,',
#    'authors',
#    'evaluate',
#    'AI',
#    'techniques',
#    'integrated',
#    'present',
#    'future',
#    'database',
#    'systems',
#    'knowledge',
#    'based',
#    'management',
#    'systems,',
#    'incorporating',
#    'AI',
#    'expertise',
#    'system',
#    'design.',
#    'The',
#    'book',
#    'also',
#    'addresses',
#    'techniques',
#    'developed',
#    'recently',
#    'directly',
#    'used,',
#    'basis,',
#    'data',
#    'retrieval',
#    'across',
#    'world',
#    'wide',
#    'web.',
#    'If',
#    'designer',
#    'developer',
#    'working',
#    'database',
#    'community,',
#    'database',
#    'AI',
#    'products',
#    'applications,',
#    'book',
#    'help',
#    'understand',
#    'crucial',
#    'research',
#    'developments',
#    'apply',
#    'results',
#    'practice.',
#    'Includes:',
#    '&middot;',
#    'Mechanisms',
#    'handling',
#    'data',
#    'knowledge',
#    'including',
#    'XML,',
#    'web',
#    'indexing,',
#    'search',
#    'engines',
#    '&',
#    'data',
#    'mining',
#    '&middot;',
#    'Object',
#    'Oriented',
#    'Database',
#    'Management',
#    'Systems',
#    'object-relational',
#    'DBMS',
#    '&middot;',
#    'Data',
#    'modeling',
#    'including',
#    'techniques',
#    'suchas',
#    'Entity',
#    'Relationship,',
#    'Functional',
#    'Data',
#    '&',
#    'Semantic',
#    'Database',
#    'models,',
#    'well',
#    'using',
#    'notations',
#    'modeling',
#    '(OMT',
#    '&',
#    'UML)',
#    'Plus!',
#    'Extended',
#    'case',
#    'studies',
#    'commercial',
#    'systems',
#    'About',
#    'authors:',
#    'Elisa',
#    'Bertino',
#    'well',
#    'known',
#    'expert',
#    'integration',
#    'AI',
#    'database',
#    'techniques,',
#    'areas',
#    'O-O,',
#    'distributed,',
#    'deductive',
#    'multimedia',
#    'databases',
#    'database',
#    'security.',
#    'She',
#    'chaired',
#    'given',
#    'tutorials',
#    'many',
#    'international',
#    'conferences',
#    'published',
#    'hundreds',
#    'journal',
#    'papers',
#    'book.',
#    'Elisa',
#    'currently',
#    'professor',
#    'computer',
#    'science',
#    'University',
#    'Milan.',
#    'Barbara',
#    'Catania',
#    'assistant',
#    'professor',
#    'computer',
#    'science',
#    'University',
#    'Genova,',
#    'specializing',
#    'deductive',
#    'multimedia',
#    'databases,',
#    'indexing',
#    'techniques',
#    'object-oriented',
#    'constraint',
#    'databases.',
#    'She',
#    'presented',
#    'number',
#    'international',
#    'conferences',
#    'co-authored',
#    'book.',
#    'Gian',
#    'Piero',
#    'Zarri',
#    'internationally',
#    'renowned',
#    'consultant',
#    'researcher',
#    'areas',
#    'knowledge-based',
#    'systems,',
#    'natural-language',
#    'processing,',
#    'databases',
#    'information',
#    'retrieval',
#    'systems.',
#    'He',
#    'editorial',
#    'board',
#    'number',
#    'international',
#    'scientific',
#    'journals',
#    'program',
#    'committee',
#    'many',
#    'conferences',
#    'Knowledge-Based',
#    'Systems.',
#    'Gian',
#    'Piero',
#    'currently',
#    'works',
#    'Research',
#    'Director',
#    'CNRS,',
#    'French',
#    'National',
#    'Centre',
#    'Scientific',
#    'Research.']},
#  {'quoted': [],
#   'title': 'TCP/IP Illustrated, Volume 1: The Protocols',
#   'authors': 'W. Richard Stevens',
#   'date': '1994',
#   'index': '94',
#   'abstract': ['TCP/IP',
#    'Illustrated,',
#    'Volume',
#    '1',
#    'complete',
#    'detailed',
#    'guide',
#    'entire',
#    'TCP/IP',
#    'protocol',
#    'suite',
#    '-',
#    'important',
#    'difference',
#    'books',
#    'subject.',
#    'Rather',
#    'describing',
#    'RFCs',
#    'say',
#    'protocol',
#    'suite',
#    'do,',
#    'unique',
#    'book',
#    'uses',
#    'popular',
#    'diagnostic',
#    'tool',
#    'may',
#    'actually',
#    'watch',
#    'protocols',
#    'action.By',
#    'forcing',
#    'various',
#    'conditions',
#    'occur',
#    '-',
#    'connection',
#    'establishment,',
#    'timeout',
#    'retransmission,',
#    'fragmentation',
#    '-',
#    'displaying',
#    'results,',
#    'TCP/IP',
#    'Illustrated',
#    'gives',
#    'much',
#    'greater',
#    'understanding',
#    'concepts',
#    'words',
#    'alone',
#    'could',
#    'provide.',
#    'Whether',
#    'new',
#    'TCP/IP',
#    'read',
#    'books',
#    'subject,',
#    'come',
#    'away',
#    'increased',
#    'understanding',
#    'TCP/IP',
#    'works',
#    'way',
#    'does,',
#    'well',
#    'enhanced',
#    'skill',
#    'developing',
#    'aplications',
#    'run',
#    'TCP/IP.']},
#  {'quoted': [],
#   'title': 'The Relational Model for Database Management, Version 2',
#   'authors': 'E. F. Codd',
#   'date': '1990',
#   'index': '112',
#   'abstract': ['From',
#    'Preface',
#    '(See',
#    'Front',
#    'Matter',
#    'full',
#    'Preface)',
#    'An',
#    'important',
#    'adjunct',
#    'precision',
#    'sound',
#    'theoretical',
#    'foundation.',
#    'The',
#    'relational',
#    'model',
#    'solidly',
#    'based',
#    'two',
#    'parts',
#    'mathematics:',
#    'firstorder',
#    'predicate',
#    'logic',
#    'theory',
#    'relations.',
#    'This',
#    'book,',
#    'however,',
#    'dwell',
#    'theoretical',
#    'foundations,',
#    'rather',
#    'features',
#    'relational',
#    'model',
#    'I',
#    'perceive',
#    'important',
#    'database',
#    'users,',
#    'therefore',
#    'DBMS',
#    'vendors.',
#    'My',
#    'perceptions',
#    'result',
#    '20',
#    'years',
#    'practical',
#    'experience',
#    'computing',
#    'data',
#    'processing',
#    '(chiefly,',
#    'exclusively,',
#    'large-scale',
#    'customers',
#    'IBM),',
#    'followed',
#    'another',
#    '20',
#    'years',
#    'research.',
#    'I',
#    'believe',
#    'first',
#    'book',
#    'deal',
#    'exclusively',
#    'relational',
#    'approach.',
#    'It',
#    'does,',
#    'however,',
#    'include',
#    'design',
#    'principles',
#    'Chapters',
#    '21',
#    '22.',
#    'It',
#    'also',
#    'first',
#    'book',
#    'relational',
#    'model',
#    'originator',
#    'model.',
#    'All',
#    'ideas',
#    'relational',
#    'model',
#    'described',
#    'book',
#    'mine,',
#    'except',
#    'cases',
#    'I',
#    'explicitly',
#    'credit',
#    'someone',
#    'else.',
#    'In',
#    'developing',
#    'relational',
#    'model,',
#    'I',
#    'tried',
#    'follow',
#    "Einstein's",
#    'advice,',
#    '"Make',
#    'simple',
#    'possible,',
#    'simpler."',
#    'I',
#    'believe',
#    'last',
#    'clause',
#    'discouraging',
#    'pursuit',
#    'simplicity',
#    'extent',
#    'distorting',
#    'reality.',
#    'So',
#    'book',
#    'contain',
#    '30',
#    'chapters',
#    'two',
#    'appendixes?',
#    'To',
#    'answer',
#    'question,',
#    'necessary',
#    'look',
#    'history',
#    'research',
#    'development',
#    'relational',
#    'model.']},
#  {'quoted': [],
#   'title': 'Java Platform Performance - Strategies and Tactics',
#   'authors': 'Steve Wilson,Jeff Kesselman',
#   'date': '2000',
#   'index': '113',
#   'abstract': [':This',
#    'book',
#    'addresses',
#    'vital',
#    'issue',
#    'developing',
#    'software',
#    'Java™',
#    'platform:',
#    'achieve',
#    'maximum',
#    'performance',
#    'scalability',
#    'applications.',
#    'Drawing',
#    "authors'",
#    'knowledge',
#    'Java',
#    'programming',
#    'language',
#    'extensive',
#    'experience',
#    'working',
#    'performance',
#    'issues,',
#    'book',
#    'reveals',
#    'common',
#    'mistakes',
#    'misconceptions',
#    'concerning',
#    'performance',
#    'characteristics',
#    'Java',
#    'technologies.',
#    'It',
#    'offers',
#    'overall',
#    'development',
#    'strategies',
#    'concrete,',
#    'battle-tested',
#    'techniques',
#    'dramatically',
#    'improve',
#    'performance',
#    'applications',
#    'constructed',
#    'Java',
#    'programming',
#    'language.',
#    'Java™',
#    'Platform',
#    'Performance',
#    'highlights',
#    'importance',
#    'integrating',
#    'performance',
#    'evaluation',
#    'application',
#    'development',
#    'process',
#    'discusses',
#    'measurement',
#    'techniques.',
#    'The',
#    'book',
#    'presents',
#    'practical',
#    'tactics',
#    'enhancing',
#    'application',
#    'performance',
#    'areas',
#    'I/O,',
#    'RAM',
#    'footprint,',
#    'small',
#    'object',
#    'management,',
#    'algorithms,',
#    'data',
#    'structures,',
#    'Swing,',
#    'deployment.',
#    'Specific',
#    'topics',
#    'covered',
#    'include:',
#    'Incorporating',
#    'performance',
#    'evaluation',
#    'development',
#    'process',
#    'Profiling',
#    'benchmarking',
#    'Building',
#    'scalable,',
#    'fast',
#    'Swing',
#    'GUIs',
#    'Using',
#    'high-speed',
#    'I/O',
#    'Computing',
#    'controlling',
#    'RAM',
#    'footprint',
#    'Reducing',
#    'number',
#    'classes',
#    'Eliminating',
#    'temporary',
#    'objects',
#    'Selecting',
#    'high-performance',
#    'algorithms',
#    'data',
#    'structures',
#    'Using',
#    'Java',
#    'native',
#    'code',
#    'applet',
#    'packaging',
#    'efficiently',
#    'Garbage',
#    'collection',
#    'Java',
#    'HotSpot™',
#    'technology',
#    'With',
#    'understanding',
#    'performance',
#    'issues',
#    'specific',
#    'techniques',
#    'reducing',
#    'overhead',
#    'discussed',
#    'book,',
#    'theinformation',
#    'need',
#    'enhance',
#    'efficiency,',
#    'speed,',
#    'scalability',
#    'software.']},
#  {'quoted': [],
#   'title': 'An Introduction to Database Systems',
#   'authors': 'C. J. Date',
#   'date': '1975',
#   'index': '117',
#   'abstract': [':The',
#    'sixth',
#    'edition',
#    'well-respected',
#    'text/reference--which',
#    'almost',
#    'completely',
#    'rewritten--continues',
#    'comprehensive',
#    'up-to-date',
#    'treatment',
#    'database',
#    'technology',
#    'currently',
#    'available.',
#    'Readers',
#    'gain',
#    'strong',
#    'working',
#    'knowledge',
#    'overall',
#    'structure,',
#    'concepts,',
#    'objectives',
#    'database',
#    'systems',
#    'become',
#    'familiar',
#    'theoretical',
#    'principles',
#    'underlying',
#    'construction',
#    'systems.']},
#  {'quoted': [],
#   'title': 'An Introduction to Database Systems, 3rd Edition',
#   'authors': 'C. J. Date',
#   'date': '1981',
#   'index': '121',
#   'abstract': [':For',
#    '25',
#    'years,',
#    'C.',
#    'J.',
#    "Date's",
#    'An',
#    'Introduction',
#    'Database',
#    'Systems',
#    'authoritative',
#    'resource',
#    'readers',
#    'interested',
#    'gaining',
#    'insight',
#    'understanding',
#    'principles',
#    'database',
#    'systems.',
#    'This',
#    'revision',
#    'continues',
#    'provide',
#    'solid',
#    'grounding',
#    'foundations',
#    'database',
#    'technology',
#    'provide',
#    'ideas',
#    'field',
#    'likely',
#    'develop',
#    'future..',
#    '"Readers',
#    'book',
#    'gain',
#    'strong',
#    'working',
#    'knowledge',
#    'overall',
#    'structure,',
#    'concepts,',
#    'objectives',
#    'database',
#    'systems',
#    'become',
#    'familiar',
#    'theoretical',
#    'principles',
#    'underlying',
#    'construction',
#    'systems.']}]

# %%
def filter_least_frequent_authors(articles, top=1000):
    authors_frequency = collections.defaultdict(int)
    for article in tqdm.tqdm(articles):
        authors = article['authors'].split(",")
        for author in authors:
            authors_frequency[author]+=1
    top_authors = list(sorted(authors_frequency.items(), key=itemgetter(1),reverse=True))
    top_authors = top_authors[:top]
    top_authors_without_occurences = [el[0] for el in top_authors]
    return top_authors_without_occurences

top_authors = filter_least_frequent_authors(articles_tokenized)
# Out:
# 100%|██████████| 529247/529247 [00:01<00:00, 497984.31it/s]

# %%
def filter_articles_containing_only_top_authors(articles, top_authors):
    
    def all_authors_in_top(article, top_authors):
        for author in article['authors'].split(","):
            if author not in top_authors:
                return False
        return True
    
    
    return [article for article in articles if all_authors_in_top(article, top_authors)]

# %%
filtered_articles = filter_articles_containing_only_top_authors(articles_tokenized, top_authors)

# %%
print (len(articles_tokenized))
print (len(filtered_articles))
# Out:
# 529247
# 5199

# %%
def calculate_frequency_of_words(articles, frequency_cap = 50):
    frequency = collections.defaultdict(int)
    for article in articles:
        for word in article['abstract']:
            frequency[word] += 1
            
    top_words = list(sorted(frequency.items(), key=itemgetter(1),reverse=True))
    top_words = [word[0] for word in top_words if word[1] > frequency_cap]
    return top_words

def filter_unfrequent_words_from_abstract(articles, top_words):
    articles_copy = copy.deepcopy(articles)
    for article in articles_copy:
        article['abstract'] = [word for word in article['abstract'] if word in top_words]
    return articles_copy
        
top_words = calculate_frequency_of_words(filtered_articles)
filtered_articles_with_frequent_words = filter_unfrequent_words_from_abstract(filtered_articles, top_words)

# %%
filtered_articles_with_frequent_words
# Out:
# [{'quoted': ['165'],
#   'title': 'Spatial Data Structures.',
#   'authors': 'Hanan Samet',
#   'date': '1995',
#   'source': 'Modern Database Systems',
#   'index': '25',
#   'abstract': ['An',
#    'overview',
#    'presented',
#    'use',
#    'spatial',
#    'data',
#    'structures',
#    'spatial',
#    'databases.',
#    'The',
#    'focus',
#    'hierarchical',
#    'data',
#    'including',
#    'number',
#    'data',
#    'respect',
#    'space',
#    'it.',
#    'Such',
#    'techniques',
#    'known',
#    'spatial',
#    'indexing',
#    'methods.',
#    'data',
#    'structures',
#    'based',
#    'recursive',
#    'They',
#    'nature',
#    'data',
#    'space',
#    'well',
#    'time',
#    'also',
#    'facilitate',
#    'operations',
#    'given',
#    'use',
#    'data',
#    'structures',
#    'representation',
#    'different',
#    'data',
#    'types']},
#  {'quoted': [],
#   'title': 'ACTA: The SAGA Continues',
#   'authors': 'Panos K. Chrysanthis,Krithi Ramamritham',
#   'date': '1992',
#   'source': 'Database Transaction Models for Advanced Applications',
#   'index': '2194',
#   'abstract': ['comprehensive',
#    'transaction',
#    'framework',
#    'transaction',
#    'effects',
#    'extended',
#    'transactions',
#    'objects',
#    'allows',
#    'specification',
#    '(1)',
#    'interactions',
#    'transactions',
#    'terms',
#    'relationships',
#    'significant',
#    'different',
#    'transactions',
#    '(2)',
#    'effects',
#    'state',
#    '(i.e.,',
#    'synchronization',
#    'extended',
#    'traditional',
#    'models',
#    'proposed',
#    'deal',
#    'involve',
#    'collaborative',
#    'One',
#    'model',
#    'independent',
#    'transactions',
#    'way',
#    'component',
#    'actions',
#    'even',
#    'However,',
#    'effects',
#    'components',
#    'After',
#    'giving',
#    'modeling',
#    'illustrate',
#    'use',
#    'giving',
#    'complete',
#    'formal',
#    'characterization',
#    'reasoning',
#    'power',
#    'shown',
#    'proving',
#    'properties',
#    'Finally,',
#    'series',
#    'variations',
#    'original',
#    'model',
#    'changes',
#    'formal',
#    'characterization']},
#  {'quoted': [],
#   'title': 'Optimizing Datalog Programs.',
#   'authors': 'Yehoshua Sagiv',
#   'date': '1988',
#   'source': 'Foundations of Deductive Databases and Logic Programming.',
#   'index': '2261',
#   'abstract': ['programs,',
#    'i.e.,',
#    'programs',
#    'without',
#    'function',
#    'considered',
#    'It',
#    'variable',
#    'rule',
#    'must',
#    'also',
#    'appear',
#    'The',
#    'input',
#    'program',
#    'set',
#    'given',
#    'addition',
#    'and,',
#    'viewed',
#    'assignment',
#    'relations',
#    'Two',
#    'programs',
#    'equivalent',
#    'produce',
#    'result',
#    'possible',
#    'relations',
#    '(i.e.,',
#    'appear',
#    'Two',
#    'programs',
#    'equivalent',
#    'produce',
#    'result',
#    'possible',
#    'initial',
#    'relations',
#    '(i.e.,',
#    'The',
#    'equivalence',
#    'problem',
#    'programs',
#    'known',
#    'It',
#    'shown',
#    'uniform',
#    'equivalence',
#    'algorithm',
#    'given',
#    'minimizing',
#    'program',
#    'uniform',
#    'A',
#    'technique',
#    'parts',
#    'program',
#    'redundant',
#    'equivalence',
#    'uniform',
#    'A',
#    'procedure',
#    'testing',
#    'uniform',
#    'equivalence',
#    'also',
#    'developed',
#    'case',
#    'database',
#    'satisfies',
#    'constraints.']},
#  {'quoted': [],
#   'title': 'Distributed Algorithms',
#   'authors': 'Nancy A. Lynch',
#   'date': '1996',
#   'index': '2339',
#   'abstract': ['provides',
#    'analyzing',
#    'distributed',
#    'algorithms.',
#    'book',
#    'wide',
#    'including',
#    'system',
#    'designers',
#    'contains',
#    'significant',
#    'algorithms',
#    'results',
#    'simple',
#    'The',
#    'algorithms',
#    'proved',
#    'complexity',
#    'analyzed',
#    'according',
#    'defined',
#    'complexity',
#    'The',
#    'problems',
#    'include',
#    'resource',
#    'among',
#    'distributed',
#    'data',
#    'global',
#    'many',
#    'The',
#    'according',
#    'system',
#    'model',
#    '-',
#    'first',
#    'timing',
#    'model',
#    'communication',
#    'The',
#    'system',
#    'models',
#    'separate',
#    'easy',
#    'The',
#    'presentation',
#    'yet',
#    'enough',
#    'This',
#    'book',
#    'important',
#    'problems,',
#    'algorithms,',
#    'results',
#    'problems',
#    'arise',
#    'apply',
#    'algorithms',
#    'solve',
#    'use',
#    'results',
#    'determine',
#    'whether',
#    'problems',
#    'The',
#    'book',
#    'also',
#    'provides',
#    'basic',
#    'mathematical',
#    'tools',
#    'designing',
#    'new',
#    'algorithms',
#    'proving',
#    'new',
#    'results.',
#    'In',
#    'addition,',
#    'reason',
#    'distributed',
#    'algorithms',
#    '-',
#    'model',
#    'required',
#    'prove',
#    'evaluate',
#    'performance',
#    'realistic']},
#  {'quoted': [],
#   'title': 'Signature Files.',
#   'authors': 'Christos Faloutsos',
#   'date': '1992',
#   'source': 'Information Retrieval: Data Structures & Algorithms',
#   'index': '2518',
#   'abstract': ['The',
#    'provide',
#    'students',
#    'working',
#    'area',
#    'computing',
#    'present',
#    'discuss',
#    'research',
#    'approaches',
#    'results.',
#    'The',
#    'around',
#    'conference',
#    'selected',
#    'research',
#    'presented.']},
#  {'quoted': ['642734',
#    '643149',
#    '1118611',
#    '951376',
#    '1118616',
#    '1118695',
#    '598255',
#    '545060',
#    '598927',
#    '642025',
#    '643492',
#    '771510',
#    '1386658',
#    '543649',
#    '1117443',
#    '599849',
#    '1127282',
#    '1118151',
#    '1064571',
#    '1196211',
#    '1118311',
#    '1118332',
#    '1118609',
#    '1196280',
#    '58',
#    '1118693'],
#   'title': 'Concurrency Control Performance Modeling: Alternatives and Implications.',
#   'authors': 'Rakesh Agrawal,Michael J. Carey,Miron Livny',
#   'date': '1996',
#   'source': 'Performance of Concurrency Control Mechanisms in Centralized Database Systems',
#   'index': '2548',
#   'abstract': ['A',
#    'number',
#    'recent',
#    'studies',
#    'performance',
#    'concurrency',
#    'control',
#    'algorithms',
#    'database',
#    'management',
#    'systems.',
#    'The',
#    'results',
#    'rather',
#    'In',
#    'paper,',
#    'rather',
#    'another',
#    'algorithm',
#    'performance',
#    'investigate',
#    'assumptions',
#    'made',
#    'models',
#    'used',
#    'past',
#    'studies',
#    'We',
#    'complete',
#    'model',
#    'database',
#    'environment',
#    'relative',
#    'performance',
#    'three',
#    'different',
#    'approaches',
#    'concurrency',
#    'control',
#    'problem',
#    'variety',
#    'modeling',
#    'The',
#    'three',
#    'approaches',
#    'studied',
#    'represent',
#    'different',
#    'transaction',
#    'assumptions',
#    'nature',
#    'database',
#    'transaction',
#    'amount',
#    'information',
#    'available',
#    'concurrency',
#    'control',
#    'algorithm',
#    'We',
#    'show',
#    'differences',
#    'underlying',
#    'assumptions',
#    'explain',
#    'performance',
#    'results.',
#    'We',
#    'also',
#    'address',
#    'question',
#    'realistic',
#    'various',
#    'assumptions',
#    'actual',
#    'database',
#    'systems.']},
#  {'quoted': [],
#   'title': 'Towards a theory of Recursive Structures.',
#   'authors': 'David Harel',
#   'date': '1995',
#   'source': 'Computer Science Today',
#   'index': '2692',
#   'abstract': ['In',
#    'computer',
#    'one',
#    'mainly',
#    'finite',
#    'objects.',
#    'infinite',
#    'objects',
#    'must',
#    'i.e.,',
#    'thus',
#    'effective',
#    'finite',
#    'This',
#    'leads',
#    'notion',
#    'recursive',
#    'recursive',
#    'structure',
#    'data',
#    'In',
#    'paper',
#    'recent',
#    'work',
#    'recursive',
#    'structures',
#    'data',
#    'including',
#    '(1)',
#    'high',
#    'many',
#    'problems',
#    'recursive',
#    'graphs,',
#    'ways',
#    'results',
#    'classification',
#    'optimization',
#    'problems',
#    'results',
#    'degree',
#    'results',
#    'query',
#    'languages',
#    'recursive',
#    'data',
#    'The',
#    'ACM',
#    'Portal',
#    'published',
#    'Association',
#    'Computing',
#    'Machinery.',
#    'Copyright',
#    '©',
#    '2010',
#    'ACM,',
#    'Inc.',
#    'Terms',
#    'Usage',
#    'Privacy',
#    'Policy',
#    'Code',
#    'Ethics',
#    'Contact',
#    'Us',
#    'Useful',
#    'downloads:',
#    'Adobe',
#    'Acrobat',
#    'QuickTime',
#    'Windows',
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': ['599467',
#    '139',
#    '599004',
#    '599166',
#    '599660',
#    '1118668',
#    '599795',
#    '599849',
#    '1118705'],
#   'title': 'Object Management in Postgres using Procedures.',
#   'authors': 'Michael Stonebraker',
#   'date': '1991',
#   'source': 'On Object-Oriented Database System',
#   'index': '2804',
#   'abstract': ['This',
#    'paper',
#    'presents',
#    'object',
#    'management',
#    'designed',
#    'data',
#    'This',
#    'system',
#    'unique',
#    'new',
#    'data',
#    'model',
#    'support',
#    'objects',
#    'instead',
#    'extend',
#    'relational',
#    'model',
#    'powerful',
#    'abstract',
#    'data',
#    'capability',
#    'procedures',
#    'data',
#    'base',
#    'objects.',
#    'The',
#    'relational',
#    'model',
#    'paper',
#    'along',
#    'relational']},
#  {'quoted': [],
#   'title': 'Temporally Invariant Junction Tree for Interference in Dynamic Bayesian Network.',
#   'authors': 'Yang Xiang',
#   'date': '1999',
#   'source': 'Artificial Intelligence Today',
#   'index': '3102',
#   'abstract': ['networks',
#    'extend',
#    'networks',
#    'static',
#    'domains',
#    'dynamic',
#    'The',
#    'known',
#    'method',
#    'exact',
#    'inference',
#    'based',
#    'dynamic',
#    'reduction',
#    'active',
#    'It',
#    'effective',
#    'domain',
#    'relatively',
#    'fast',
#    'domain',
#    'inference',
#    'time',
#    'This',
#    'study',
#    'feature',
#    'problem',
#    'domains',
#    'improve',
#    'efficiency',
#    'exact',
#    'inference',
#    'We',
#    'propose',
#    'construction',
#    'directly',
#    'supporting',
#    'exact',
#    'inference',
#    'discuss',
#    'issues',
#    'This',
#    'method',
#    'need',
#    'computation',
#    'associated',
#    'dynamic',
#    'reduction',
#    'existing',
#    'method.',
#    'The',
#    'method',
#    'demonstrated',
#    'experimental']},
#  {'quoted': [],
#   'title': 'Grading Knowledge, Extracting Degree Information from Texts.',
#   'authors': 'Steffen Staab',
#   'date': '1999',
#   'source': 'Lecture Notes in Computer Science',
#   'index': '3551',
#   'abstract': ['natural',
#    'language',
#    'formal',
#    'representation',
#    'text',
#    'knowledge',
#    'methods',
#    'show',
#    'lack',
#    'methods',
#    'understanding',
#    'natural',
#    'language',
#    'like',
#    'hard',
#    'disk',
#    'describe',
#    'properties',
#    'like',
#    'respectively.',
#    'However,',
#    'without',
#    'understanding',
#    'degree',
#    'expressions',
#    'often',
#    'central',
#    'This',
#    'book',
#    'shows',
#    'comprehensive',
#    'concepts',
#    'degree',
#    'information',
#    'natural',
#    'language',
#    'It',
#    'task',
#    'three',
#    'levels',
#    'natural',
#    'language',
#    'degree',
#    'representing',
#    'On',
#    'three',
#    'author',
#    'shows',
#    'approaches',
#    'degree',
#    'understanding',
#    'problem',
#    'since',
#    'large',
#    'role',
#    'knowledge',
#    'Thus,',
#    'gives',
#    'verification',
#    'central',
#    'knowledge',
#    'This',
#    'construction',
#    'First,',
#    'author',
#    'gives',
#    'overview',
#    'information',
#    'system.',
#    'Then,',
#    'review',
#    'relevant',
#    'author',
#    'two',
#    'natural',
#    'language',
#    'degree',
#    'expressions',
#    'proposes',
#    'algorithms',
#    'handle',
#    'system.',
#    'These',
#    'methods',
#    'applied',
#    'two',
#    'text',
#    'medical',
#    'diagnosis',
#    'domain',
#    'information',
#    'Moreover,',
#    'author',
#    'well-known',
#    'constraint',
#    'This',
#    'generalization',
#    'representing',
#    'reasoning',
#    'natural',
#    'language',
#    'degree',
#    'also',
#    'interesting',
#    'point',
#    'view',
#    'field',
#    'temporal',
#    'The',
#    'book',
#    'gives',
#    'integration',
#    'three',
#    'levels',
#    'understanding',
#    'showing',
#    'leads',
#    'even',
#    'advanced',
#    '--',
#    'efficient',
#    '--',
#    'performance',
#    'proposed']},
#  {'quoted': [],
#   'title': 'Web Data Mining: Exploring Hyperlinks, Contents, and Usage Data',
#   'authors': 'Bing Liu',
#   'date': '2007',
#   'source': 'Data-Centric Systems and Applications',
#   'index': '3635',
#   'abstract': ['Web',
#    'mining',
#    'useful',
#    'information',
#    'knowledge',
#    'Web',
#    'page',
#    'data.',
#    'Although',
#    'Web',
#    'mining',
#    'uses',
#    'many',
#    'conventional',
#    'data',
#    'mining',
#    'techniques,',
#    'application',
#    'traditional',
#    'data',
#    'mining',
#    'due',
#    'nature',
#    'Web',
#    'data',
#    'It',
#    'also',
#    'developed',
#    'many',
#    'algorithms',
#    'techniques.',
#    'written',
#    'comprehensive',
#    'text',
#    'Web',
#    'data',
#    'topics',
#    'structure',
#    'mining,',
#    'content',
#    'mining,',
#    'mining',
#    'book',
#    'together',
#    'essential',
#    'concepts',
#    'algorithms',
#    'related',
#    'areas',
#    'data',
#    'mining,',
#    'machine',
#    'text',
#    'processing',
#    'form',
#    'The',
#    'book',
#    'offers',
#    'rich',
#    'theory',
#    'addressing',
#    'research',
#    'well',
#    'technology',
#    'practical',
#    'point',
#    'It',
#    'suitable',
#    'researchers',
#    'Web',
#    'mining',
#    'learning',
#    'text',
#    'use',
#    'classes',
#    'data',
#    'mining,',
#    'Web',
#    'mining,',
#    'Web',
#    'implemented',
#    'algorithms',
#    'available',
#    'The',
#    'ACM',
#    'Portal',
#    'published',
#    'Association',
#    'Computing',
#    'Machinery.',
#    'Copyright',
#    '©',
#    '2010',
#    'ACM,',
#    'Inc.',
#    'Terms',
#    'Usage',
#    'Privacy',
#    'Policy',
#    'Code',
#    'Ethics',
#    'Contact',
#    'Us',
#    'Useful',
#    'downloads:',
#    'Adobe',
#    'Acrobat',
#    'QuickTime',
#    'Windows',
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': [],
#   'title': 'Software Architectures for Task-Oriented Computing.',
#   'authors': 'David Garlan',
#   'date': '2008',
#   'source': 'ACIS-ICIS',
#   'index': '4966',
#   'abstract': ['Recent',
#    'advances',
#    'ubiquitous',
#    'computing,',
#    'computing,',
#    'intelligence',
#    'led',
#    'better',
#    'support',
#    'tasks',
#    'intelligence',
#    'computing',
#    'This',
#    'infrastructure',
#    'computing',
#    'resources',
#    'applications',
#    'one',
#    'hand,',
#    "user's",
#    'high-level',
#    'goals',
#    'In',
#    'talk',
#    'I',
#    'survey',
#    'recent',
#    'research',
#    'developing',
#    'software',
#    'architectures',
#    'support',
#    'new',
#    'features',
#    'architectures',
#    'ability',
#    'interface',
#    'applications,',
#    'still',
#    'considerable',
#    'support',
#    'user',
#    'ability',
#    'machine',
#    'learning',
#    'system',
#    'user',
#    'ability',
#    'resource',
#    'user',
#    'I',
#    'software',
#    'engineering',
#    'challenges',
#    'arise']},
#  {'quoted': ['789354'],
#   'title': 'Your way your missions: from location-based to route-based pervasive gaming.',
#   'authors': 'Ling Chen,Steve Benford',
#   'date': '2007',
#   'source': 'Advances in Computer Entertainment Technology',
#   'index': '5113',
#   'abstract': ['In',
#    'paper,',
#    'describe',
#    'design',
#    'implementation',
#    'game',
#    'named',
#    'Since',
#    'game',
#    'play',
#    'game',
#    'without',
#    'changing',
#    'A',
#    'method',
#    'proposed',
#    'obtain',
#    'corresponding',
#    'tool',
#    'developed',
#    'upon',
#    'Two',
#    'approaches',
#    'adaptation',
#    'spatial',
#    'databases',
#    'presented.']},
#  {'quoted': ['57554', '55879', '459930'],
#   'title': 'Metaphorical affect sensing in an intelligent conversational agent.',
#   'authors': 'Li Zhang',
#   'date': '2008',
#   'source': 'Advances in Computer Entertainment Technology',
#   'index': '5393',
#   'abstract': ['We',
#    'report',
#    'new',
#    'developments',
#    'affect',
#    'detection',
#    'component',
#    'processing',
#    'several',
#    'different',
#    'types',
#    'The',
#    'component',
#    'embedded',
#    'intelligent',
#    'AI',
#    'agent',
#    'human',
#    'users',
#    'The',
#    'detected',
#    'states',
#    'also',
#    'play',
#    'important',
#    'role',
#    'affect',
#    'detection',
#    'component',
#    'Our',
#    'work',
#    'conference',
#    'interaction',
#    'based',
#    'affect',
#    'computing,',
#    'learning',
#    'evaluation',
#    'social']},
#  {'quoted': [],
#   'title': 'Making Use: Scenarios and Scenario-Based Design.',
#   'authors': 'John M. Carroll',
#   'date': '2000',
#   'source': 'Symposium on Designing Interactive Systems',
#   'index': '5571',
#   'abstract': ['interaction',
#    'help',
#    'us',
#    'understand',
#    'create',
#    'computer',
#    'systems',
#    'applications',
#    'human',
#    'activity',
#    'human',
#    'activity',
#    'learn',
#    'tools',
#    'use',
#    'work,',
#    'media',
#    'design',
#    'offers',
#    'significant',
#    'unique',
#    'challenges',
#    'design',
#    'content',
#    'design',
#    'work,',
#    'developers',
#    'design',
#    'action',
#    'developers',
#    'design',
#    'multiple',
#    'views',
#    'diverse',
#    'kinds',
#    'developers',
#    'many',
#    'given',
#    'design',
#    'also',
#    'designers',
#    'reuse',
#    'address',
#    'challenge',
#    'technical',
#    'knowledge',
#    'often',
#    'needs',
#    'technical',
#    'design.',
#    'Finally,',
#    'communication',
#    'among',
#    'make',
#    'design',
#    'activities',
#    'great',
#    'variety',
#    'design,',
#    'addressing',
#    'challenge',
#    'often',
#    'attention',
#    'needs',
#    'concerns',
#    'people',
#    'use',
#    'Computer',
#    'He',
#    'written',
#    'technical',
#    'conference',
#    'including',
#    'work',
#    'technology',
#    'system',
#    'development',
#    'Design',
#    'methods',
#    'techniques',
#    'beyond',
#    'The',
#    'design',
#    'interactions']},
#  {'quoted': ['893021'],
#   'title': 'Scenario-based usability engineering.',
#   'authors': 'Mary Beth Rosson,John M. Carroll',
#   'date': '2002',
#   'source': 'Symposium on Designing Interactive Systems',
#   'index': '5711',
#   'abstract': ['This',
#    'tutorial',
#    'introduces',
#    'approach',
#    'engineering',
#    'user',
#    'interaction',
#    'central',
#    'The',
#    'includes',
#    'overview',
#    'group',
#    'analysis',
#    'design',
#    'general']},
#  {'quoted': [],
#   'title': 'E-procurement and market evolution: an evolutionary game approach.',
#   'authors': 'Wei Jiang',
#   'date': '2005',
#   'source': 'ICEC',
#   'index': '5812',
#   'abstract': ['negative',
#    'making',
#    'market',
#    'choice',
#    'online',
#    'game',
#    'paper',
#    'presents',
#    'one',
#    'first',
#    'market',
#    'evolution',
#    'By',
#    'developing',
#    'model,',
#    'addresses',
#    'factors',
#    'market',
#    'basic',
#    'rules',
#    'market',
#    'traditional',
#    'It',
#    'built',
#    'effort',
#    'power',
#    'share',
#    'benefits',
#    'Simulation',
#    'broad',
#    'based',
#    'assumptions',
#    'paper',
#    'initial',
#    'analytical',
#    'basis',
#    'extended',
#    'model',
#    'future',
#    'research.']},
#  {'quoted': ['211658', '971894', '1061555'],
#   'title': 'Automated mechanism design: complexity results stemming from the single-agent setting.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2003',
#   'source': 'ICEC',
#   'index': '5943',
#   'abstract': ['The',
#    'aggregation',
#    'preferences',
#    'central',
#    'problem',
#    'multiagent',
#    'systems.',
#    'The',
#    'key',
#    'agents',
#    'may',
#    'report',
#    'preferences',
#    'design',
#    'art',
#    'designing',
#    'rules',
#    'game',
#    'agents',
#    'motivated',
#    'report',
#    'preferences',
#    'desirable',
#    'We',
#    'propose',
#    'approach',
#    'mechanism',
#    'automatically',
#    'created',
#    'aggregation',
#    'setting',
#    'This',
#    'several',
#    'mechanism',
#    'design',
#    'optimization',
#    'problem',
#    'needs',
#    'solved',
#    'time.',
#    'computational',
#    'complexity',
#    'mechanism',
#    'design',
#    'becomes',
#    'key',
#    'In',
#    'paper',
#    'analyze',
#    'mechanism',
#    'design',
#    'problem,',
#    'whose',
#    'allows',
#    'generally',
#    'applicable',
#    'show',
#    'designing',
#    'optimal',
#    'deterministic',
#    'mechanism',
#    'use',
#    'even',
#    'one',
#    'agent',
#    'whose',
#    'type',
#    'objective',
#    'social',
#    'We',
#    'show',
#    'result',
#    'extends',
#    'multiple',
#    'agents',
#    'information.',
#    'We',
#    'show',
#    'mechanism',
#    'allowed',
#    'use',
#    'design',
#    'problem',
#    'linear',
#    'programming',
#    'general',
#    'hence',
#    'This',
#    'fixed',
#    'number',
#    'agents.',
#    'We',
#    'study',
#    'possible',
#    'preferences',
#    'We',
#    'show',
#    'objective',
#    'social',
#    'optimal',
#    'deterministic',
#    'mechanism',
#    'easy',
#    'fact,',
#    'mechanism',
#    'also',
#    'We',
#    'show',
#    'designing',
#    'optimal',
#    'deterministic',
#    'mechanism',
#    'general',
#    'extends',
#    'multiple',
#    'agents.',
#    'Finally,',
#    'show',
#    'optimal',
#    'randomized',
#    'mechanism',
#    'designed',
#    'polynomial',
#    'time',
#    'using',
#    'linear',
#    'programming',
#    'even',
#    'general',
#    'objective',
#    'functions.',
#    'This',
#    'fixed',
#    'number',
#    'agents.']},
#  {'quoted': ['202436'],
#   'title': 'A novel solution to mass information storage.',
#   'authors': 'Jun Liu',
#   'date': '2005',
#   'source': 'ICEC',
#   'index': '6055',
#   'abstract': ['With',
#    'growing',
#    'network',
#    'information,',
#    'critical',
#    'demand',
#    'information',
#    'storage',
#    'storage',
#    'systems',
#    'created',
#    'based',
#    'local',
#    'area',
#    'network',
#    'difficult',
#    'satisfy',
#    'requirements',
#    'applications.',
#    'The',
#    'concept',
#    'storage',
#    'network',
#    'implement',
#    'data',
#    'access',
#    'block',
#    'level',
#    'storage',
#    'The',
#    'architecture',
#    'system',
#    'based',
#    'protocol',
#    'presented',
#    'prototype',
#    'developed',
#    'performance',
#    'Experimental',
#    'results',
#    'show',
#    'system',
#    'works',
#    'good',
#    'performance.',
#    'It',
#    'offers',
#    'novel',
#    'solution',
#    'information',
#    'storage',
#    'applications.']},
#  {'quoted': [],
#   'title': 'Expressive commerce and its application to sourcing: how we conducted $35 billion of generalized combinatorial auctions.',
#   'authors': 'Tuomas Sandholm',
#   'date': '2007',
#   'source': 'ICEC',
#   'index': '6238',
#   'abstract': ['several',
#    'services',
#    'We',
#    'introduced',
#    'new',
#    'paradigm',
#    'called',
#    'applied',
#    'It',
#    'combines',
#    'advantages',
#    'highly',
#    'human',
#    'advantages',
#    'electronic',
#    'The',
#    'idea',
#    'demand',
#    'expressed',
#    'greater',
#    'traditional',
#    'electronic',
#    'This',
#    'efficiency',
#    'improvement',
#    'allocation',
#    'market',
#    'problem',
#    'highly',
#    'complex',
#    'combinatorial',
#    'optimization',
#    'problem.',
#    'We',
#    'developed',
#    'tree',
#    'search',
#    'algorithms',
#    'solving',
#    'it.',
#    'We',
#    'using',
#    'created',
#    'The',
#    'also',
#    'able',
#    'express',
#    'production',
#    'problem',
#    'networks',
#    'understanding',
#    'implemented',
#    'instead']},
#  {'quoted': [],
#   'title': "Probe into construction of e-commerce major in undergraduate degree: the experience of Xi'an institute of post and telecoms.",
#   'authors': 'Li Zhang,Qi Li',
#   'date': '2005',
#   'source': 'ICEC',
#   'index': '6249',
#   'abstract': ['The',
#    'point',
#    'paper',
#    'practice',
#    'major',
#    'construction',
#    'focused',
#    'information',
#    'technology',
#    'After',
#    'literature',
#    'applied',
#    'commercial',
#    'gives',
#    'experience',
#    'including',
#    'learning',
#    'capability',
#    'system,',
#    'process,',
#    'specific',
#    'features',
#    'program',
#    'given',
#    'They',
#    'continuous',
#    'scheme',
#    'computer',
#    'science',
#    'Finally,',
#    'future',
#    'changes',
#    'The',
#    'may',
#    'technology',
#    'business',
#    'market',
#    'analysis']},
#  {'quoted': [],
#   'title': 'Polar opposites: next generation languages and architectures.',
#   'authors': 'Kathryn S. McKinley',
#   'date': '2004',
#   'source': 'Memory System Performance',
#   'index': '6308',
#   'abstract': ['hardware',
#    'technology',
#    'modern',
#    'programming',
#    'programming',
#    'languages',
#    'programmers',
#    'high-level',
#    'object-oriented',
#    'languages',
#    'C']},
#  {'quoted': ['1080536'],
#   'title': 'Segmented winner trees.',
#   'authors': 'Andrew Lim,Sartaj Sahni',
#   'date': '1992',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '6535',
#   'abstract': ['A',
#    'new',
#    'data',
#    'This',
#    'useful',
#    'one',
#    'needs',
#    'represent',
#    'data',
#    'The',
#    'operations',
#    'efficiently',
#    'supported',
#    'unit',
#    'length',
#    'find',
#    'least',
#    'value',
#    'given',
#    'update',
#    'two']},
#  {'quoted': ['220928', '891539', '776871', '112935', '1120358'],
#   'title': 'An FSM model for situation-aware mobile application software systems.',
#   'authors': 'Yu Wang',
#   'date': '2004',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '6719',
#   'abstract': ['desirable',
#    'feature',
#    'application',
#    'software',
#    'systems',
#    'mobile',
#    'computing',
#    'In',
#    'paper,',
#    'present',
#    'extended',
#    'finite',
#    'state',
#    'machine',
#    'model',
#    'mobile',
#    'application',
#    'software',
#    'systems.',
#    'In',
#    'model,',
#    'state',
#    'represents',
#    'condition',
#    'system',
#    'state',
#    'context',
#    'internal',
#    'action',
#    'Each',
#    'state',
#    'transition',
#    'model',
#    'represents',
#    'context',
#    'The',
#    'whole',
#    'finite',
#    'state',
#    'machine',
#    'models',
#    'application',
#    'software',
#    'system',
#    'behavior',
#    'according',
#    'The',
#    'corresponding',
#    'This',
#    'model',
#    'useful',
#    'mobile',
#    'application',
#    'software',
#    'used',
#    'used',
#    'generate',
#    'test',
#    'cases',
#    'represent',
#    'changes',
#    'system',
#    'may',
#    'experience',
#    'mobile',
#    'environment.']},
#  {'quoted': ['199234', '334661', '674922'],
#   'title': 'An improved society of hill-climbers and its application on batch process scheduling.',
#   'authors': 'Lei Zhang',
#   'date': '2005',
#   'source': 'ACM Southeast Regional Conference (1)',
#   'index': '7007',
#   'abstract': ['powerful',
#    'optimization',
#    'algorithm',
#    'large',
#    'range',
#    'problems.',
#    'But',
#    'performance',
#    'algorithm',
#    'sensitive',
#    'must',
#    'determined',
#    'user',
#    'based',
#    'problem.',
#    'In',
#    'performance',
#    'different',
#    'rate',
#    'evaluated',
#    'series',
#    'large',
#    'problems',
#    'robust',
#    'problems',
#    'algorithm',
#    'applied',
#    'important',
#    'type',
#    'optimization',
#    'problem,',
#    'scheduling',
#    'problem',
#    'process.',
#    'The',
#    'results',
#    'show',
#    'powerful',
#    'method',
#    'solving',
#    'process',
#    'scheduling',
#    'problems',
#    'widely',
#    'used']},
#  {'quoted': [],
#   'title': 'Application of particle swarm optimization on batch process scheduling.',
#   'authors': 'Lei Zhang',
#   'date': '2005',
#   'source': 'ACM Southeast Regional Conference (1)',
#   'index': '7028',
#   'abstract': ['The',
#    'scheduling',
#    'process',
#    'problem',
#    'interest',
#    'research',
#    'many',
#    'years.',
#    'methods',
#    'applied',
#    'solve',
#    'problems',
#    'efficient',
#    'algorithm.',
#    'But',
#    'problem',
#    'size',
#    'In',
#    'work,',
#    'optimization',
#    'applied',
#    'solve',
#    'scheduling',
#    'problem',
#    'process.',
#    'The',
#    'results',
#    'show',
#    'powerful',
#    'method',
#    'solving',
#    'process',
#    'scheduling',
#    'problems',
#    'widely',
#    'used']},
#  {'quoted': ['131653'],
#   'title': 'Upgrading arc problem with budget constraint.',
#   'authors': 'Li Zhang',
#   'date': '2005',
#   'source': 'ACM Southeast Regional Conference (1)',
#   'index': '7039',
#   'abstract': ['often',
#    'used',
#    'systems.',
#    'In',
#    'real',
#    'world',
#    'pair',
#    'nodes',
#    'using',
#    'using',
#    'instead',
#    'pair',
#    'network',
#    'using',
#    'higher',
#    'speed',
#    'pair',
#    'network.',
#    'These',
#    'times',
#    'network',
#    'critical',
#    'achieving',
#    'This',
#    'paper',
#    'introduces',
#    'problem',
#    'We',
#    'show',
#    'problem',
#    'general',
#    'present',
#    'several']},
#  {'quoted': ['627126', '588498'],
#   'title': 'Statistical performance critical path analysis for service-oriented systems.',
#   'authors': 'Rui Zhang',
#   'date': '2007',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '7118',
#   'abstract': ['In',
#    'order',
#    'efficient',
#    'performance',
#    'management',
#    'efforts',
#    'must',
#    'focused',
#    'services',
#    'critical',
#    'This',
#    'paper',
#    'flexible',
#    'approach',
#    'identifying',
#    'services',
#    'via',
#    'statistical',
#    'extension',
#    'critical',
#    'path',
#    'algorithm',
#    'The',
#    'solution']},
#  {'quoted': ['523715', '806946', '666401'],
#   'title': 'Reboot-based self-healing strategies for service-oriented systems.',
#   'authors': 'Rui Zhang',
#   'date': '2007',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '7155',
#   'abstract': ['As',
#    'high',
#    'availability',
#    'extends',
#    'increasingly',
#    'popular',
#    'complex',
#    'systems,',
#    'need',
#    'capabilities',
#    'become',
#    'We',
#    'demand',
#    'exploiting',
#    'standard',
#    'software.',
#    'designed',
#    'problems',
#    'service']},
#  {'quoted': ['772795', '773380', '776021'],
#   'title': 'Variations on the binary buddy system for dynamic memory management.',
#   'authors': 'Arie E. Kaufman',
#   'date': '1980',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '7372',
#   'abstract': ['Two',
#    'new',
#    'variations',
#    'binary',
#    'system',
#    'dynamic',
#    'storage',
#    'These',
#    'system',
#    'system,',
#    'smaller',
#    'memory',
#    'blocks',
#    'upon',
#    'attempt',
#    'processor',
#    'execution',
#    'time.',
#    'Simulation',
#    'results',
#    'three',
#    'systems',
#    'two',
#    'new',
#    'variations',
#    'original',
#    'system,',
#    'since',
#    'faster',
#    'difference',
#    'memory',
#    'A',
#    'comparison',
#    'system',
#    'system',
#    'performance.']},
#  {'quoted': [],
#   'title': 'A Universal Construction for Concurrent Objects.',
#   'authors': 'Rachid Guerraoui,Michel Raynal',
#   'date': '2007',
#   'source': 'ARES',
#   'index': '7604',
#   'abstract': ['A',
#    'concurrent',
#    'object',
#    'object',
#    'several',
#    'processes.',
#    'A',
#    'implementation',
#    'object',
#    'operation',
#    'process',
#    'finite',
#    'number',
#    'behavior',
#    'processes',
#    'even',
#    'An',
#    'object',
#    'type',
#    'universal',
#    'objects',
#    'together',
#    'atomic',
#    'allows',
#    'implementing',
#    'concurrent',
#    'object',
#    'defined',
#    'sequential',
#    'A',
#    'universal',
#    'construction',
#    'algorithm,',
#    'based',
#    'atomic',
#    'universal',
#    'that,',
#    'given',
#    'sequential',
#    'object',
#    'type',
#    'provides',
#    'processes',
#    'concurrent',
#    'object',
#    'type',
#    'In',
#    'paper',
#    'shown',
#    'objects',
#    'presented',
#    'universal']},
#  {'quoted': [],
#   'title': 'Concurrency Control using Subject- and Purpose-Oriented (SPO) View.',
#   'authors': 'Tomoya Enokido,Makoto Takizawa',
#   'date': '2007',
#   'source': 'ARES',
#   'index': '7652',
#   'abstract': ['In',
#    'information',
#    'systems,',
#    'multiple',
#    'transactions',
#    'objects',
#    'access',
#    'requests',
#    'multiple',
#    'transactions',
#    'There',
#    'various',
#    'ways',
#    'order',
#    'multiple',
#    'access',
#    'requests',
#    'like',
#    'ordering',
#    'In',
#    'scheduling',
#    'ways',
#    'operating',
#    'systems',
#    'highly',
#    'processes',
#    'performed',
#    'lower',
#    'In',
#    'paper,',
#    'access',
#    'request',
#    'significant',
#    'subject',
#    'performed',
#    'prior',
#    'another',
#    'access',
#    'request',
#    'less',
#    'significant',
#    'We',
#    'define',
#    'terms',
#    'In',
#    'access',
#    'control',
#    'model,',
#    'role',
#    'set',
#    'access',
#    'subject',
#    'role',
#    'issue',
#    'access',
#    'request',
#    'two',
#    'order',
#    'A',
#    'method',
#    'significant',
#    'subject',
#    'performed',
#    'another',
#    'method',
#    'less',
#    'significant',
#    'subject',
#    'A',
#    'transaction',
#    'subject',
#    'associated',
#    'subset',
#    'A',
#    'method',
#    'significant',
#    'purpose',
#    'performed',
#    'another',
#    'method',
#    'less',
#    'significant',
#    'purpose',
#    'In',
#    'paper,',
#    'discuss',
#    'methods',
#    'unique']},
#  {'quoted': [],
#   'title': 'A Hybrid Neural Network Learning System.',
#   'authors': 'Yong Liu',
#   'date': '2004',
#   'source': 'CIT',
#   'index': '8222',
#   'abstract': ['This',
#    'paper',
#    'presents',
#    'hybrid',
#    'learning',
#    'system',
#    'learning',
#    'designing',
#    'neural',
#    'network',
#    'based',
#    'learning',
#    'learning.',
#    'There',
#    'two',
#    'terms',
#    'performance',
#    'function',
#    'one',
#    'learning.',
#    'neural',
#    'network',
#    'could',
#    'learn',
#    'target',
#    'output',
#    'much',
#    'possible',
#    'training',
#    'data.',
#    'By',
#    'neural',
#    'networks',
#    'learn',
#    'simultaneously',
#    'cover',
#    'different',
#    'parts',
#    'training',
#    'data',
#    'order',
#    'learn',
#    'whole',
#    'training',
#    'data.',
#    'The',
#    'learning',
#    'hybrid',
#    'learning',
#    'system',
#    'studied',
#    'based',
#    'among',
#    'individual',
#    'networks']},
#  {'quoted': [],
#   'title': 'Protein Structure Prediction and Interpretation with Support Vector Machines and Decision Trees.',
#   'authors': 'Yi Pan',
#   'date': '2005',
#   'source': 'CIT',
#   'index': '8325',
#   'abstract': ['structures',
#    'sequences',
#    'using',
#    'computers',
#    'important',
#    'step',
#    '3D',
#    'structures',
#    'functions',
#    'hence',
#    'theoretical',
#    'practical',
#    'areas',
#    'engineering',
#    'design.',
#    'In',
#    'talk,',
#    'discuss',
#    'new',
#    'results',
#    'structure',
#    'prediction',
#    'using',
#    'We',
#    'also',
#    'discuss',
#    'use',
#    'combination',
#    'understand',
#    'prediction',
#    'rule',
#    'good',
#    'useful',
#    'experiments',
#    'may',
#    'lead',
#    'prediction',
#    'A',
#    'novel',
#    'approach',
#    'rule',
#    'clustering',
#    'generation',
#    'also',
#    'briefly',
#    'discussed.']},
#  {'quoted': [],
#   'title': 'Evolutionary Programming with Operator Adaptation.',
#   'authors': 'Yong Liu',
#   'date': '2007',
#   'source': 'CIT',
#   'index': '8727',
#   'abstract': ['This',
#    'paper',
#    'investigated',
#    'programming',
#    'adaptation',
#    'level',
#    'The',
#    'update',
#    'level',
#    'feedback',
#    'applied',
#    'change',
#    'individual',
#    'Experimental',
#    'shown',
#    'long',
#    'could',
#    'smaller',
#    'average',
#    'step',
#    'evolution',
#    'step',
#    'distribution',
#    'values',
#    'could',
#    'become',
#    'long',
#    'applied',
#    'rather',
#    'low']},
#  {'quoted': [],
#   'title': 'Concept Formation and Learning: A Cognitive Informatics Perspectiv.',
#   'authors': 'Yiyu Yao',
#   'date': '2004',
#   'source': 'IEEE ICCI',
#   'index': '9019',
#   'abstract': ['basic',
#    'human',
#    'intelligence',
#    'perspective',
#    'framework',
#    'concept',
#    'learning.',
#    'It',
#    'combines',
#    'science',
#    'machine',
#    'learning',
#    'approaches.',
#    'The',
#    'issues',
#    'various',
#    'views',
#    'concepts',
#    'learning',
#    'methods',
#    'presented',
#    'based',
#    'classical',
#    'view']},
#  {'quoted': [],
#   'title': 'Exploring Sub-Block Value Reuse for Superscalar Processors.',
#   'authors': 'Jian Huang,David J. Lilja',
#   'date': '2000',
#   'source': 'IEEE PACT',
#   'index': '9701',
#   'abstract': ['The',
#    'performance',
#    'potential',
#    'value',
#    'reuse',
#    'mechanism',
#    'depends',
#    'reuse',
#    'detection',
#    'time,',
#    'number',
#    'amount',
#    'work',
#    'reuse',
#    'Since',
#    'larger',
#    'instruction',
#    'groups',
#    'typically',
#    'reuse',
#    'opportunities',
#    'smaller',
#    'also',
#    'provide',
#    'greater',
#    'benefit',
#    'process,',
#    'important',
#    'find',
#    'point',
#    'provides',
#    'overall',
#    'performance',
#    'We',
#    'propose',
#    'new',
#    'mechanism',
#    'called',
#    'reuse',
#    'reuse',
#    'number',
#    'reuse',
#    'Our',
#    'simulation',
#    'results',
#    'show',
#    'reuse',
#    'compiler',
#    'consistent',
#    'potential',
#    'improve',
#    'performance']},
#  {'quoted': [],
#   'title': 'Instruction Scheduling for Clustered VLIW DSPs.',
#   'authors': 'Rainer Leupers',
#   'date': '2000',
#   'source': 'IEEE PACT',
#   'index': '9754',
#   'abstract': ['Recent',
#    'digital',
#    'signal',
#    'processors',
#    'show',
#    'data',
#    'path',
#    'allows',
#    'C',
#    'generate',
#    'efficient',
#    'However,',
#    'still',
#    'special',
#    'code',
#    'generation',
#    'In',
#    'order',
#    'reduce',
#    'number',
#    'register',
#    'file',
#    'needed',
#    'provide',
#    'data',
#    'multiple',
#    'functional',
#    'working',
#    'data',
#    'path',
#    'may',
#    'several',
#    'limited',
#    'capabilities',
#    'values',
#    'different',
#    'An',
#    'example',
#    'well-known',
#    'For',
#    'tasks',
#    'scheduling',
#    'partitioning',
#    'clusters',
#    'highly',
#    'This',
#    'paper',
#    'presents',
#    'new',
#    'instruction',
#    'scheduling',
#    'approach,',
#    'contrast',
#    'earlier',
#    'work,',
#    'partitioning',
#    'scheduling',
#    'single',
#    'achieve',
#    'high',
#    'code',
#    'We',
#    'show',
#    'proposed',
#    'technique',
#    'generating',
#    'efficient',
#    'code',
#    'commercial',
#    'code']},
#  {'quoted': [],
#   'title': 'XML Data Services.',
#   'authors': 'Michael J. Carey',
#   'date': '2005',
#   'source': 'IEEE SCC',
#   'index': '10033',
#   'abstract': ['We',
#    'address',
#    'new',
#    'world',
#    'Web',
#    'services',
#    'architectures',
#    'data',
#    'We',
#    'data',
#    'modeling',
#    'concepts',
#    'world',
#    'services,',
#    'approach',
#    'data',
#    'access',
#    'collection',
#    'data',
#    'services.',
#    'We',
#    'show',
#    'approach',
#    'XML',
#    'XML',
#    'Web',
#    'services,',
#    'We',
#    'show',
#    'approach',
#    'provides',
#    'uniform',
#    'framework',
#    'data',
#    'underlying',
#    'including',
#    'data',
#    'sources',
#    'well',
#    'data',
#    'Web',
#    'services.',
#    'We',
#    'also',
#    'show',
#    'approach',
#    'yields',
#    'data',
#    'services',
#    'easily',
#    'efficiently']},
#  {'quoted': [],
#   'title': 'Trust2: Developing Trust in Peer-to-Peer Environments.',
#   'authors': 'Yan Wang,Vijay Varadharajan',
#   'date': '2005',
#   'source': 'IEEE SCC',
#   'index': '10174',
#   'abstract': ['In',
#    'needs',
#    'services',
#    'This',
#    'requires',
#    'trust',
#    'evaluation',
#    'prior',
#    'This',
#    'paper',
#    'presents',
#    'novel',
#    'dynamic',
#    'trust',
#    'evaluation',
#    'model,',
#    'measure',
#    'thus',
#    'noise',
#    'obtain',
#    'accurate',
#    'objective',
#    'trust',
#    'In',
#    'model,',
#    'prior',
#    'trust',
#    'value',
#    'results',
#    'given',
#    'trust',
#    'values',
#    'results',
#    'In',
#    'aggregation',
#    'trust',
#    'weight',
#    'becomes',
#    'higher',
#    'process,',
#    'This',
#    'leads',
#    'filtering',
#    'low',
#    'improvement',
#    'trust']},
#  {'quoted': ['989727',
#    '1126068',
#    '1275561',
#    '1082411',
#    '408591',
#    '1124810',
#    '1126141',
#    '1123685',
#    '419514',
#    '807828',
#    '1079907'],
#   'title': 'Optimal Broadcasting in Injured Hypercubes Using Directed Safety Levels.',
#   'authors': 'Jie Wu',
#   'date': '2001',
#   'source': 'ISCA PDCS',
#   'index': '10764',
#   'abstract': ['communication',
#    'faulty',
#    'using',
#    'directed',
#    'safety',
#    'levels',
#    'studied',
#    'paper.',
#    'In',
#    'approach,',
#    'node',
#    'hypercube',
#    'associated',
#    'sequence',
#    'directed',
#    'safety',
#    'A',
#    'directed',
#    'safety',
#    'level',
#    'associated',
#    'node',
#    'measure',
#    'broadcast',
#    'capability',
#    'performing',
#    'optimal',
#    '-',
#    'By',
#    'optimal',
#    'broadcast',
#    'message',
#    'shortest',
#    'path',
#    '(i.e.,',
#    'length',
#    'path',
#    'distance',
#    'source',
#    'safety',
#    'levels',
#    'based',
#    'special',
#    'scheme',
#    'generalized',
#    'safety',
#    'level',
#    'model',
#    'n',
#    '-',
#    '1',
#    'information',
#    'among',
#    'nodes.',
#    'In',
#    'model,',
#    'fault',
#    'information',
#    'nodes',
#    'within',
#    'represented',
#    'better',
#    'capture',
#    'link',
#    'fault',
#    'information',
#    'nodes',
#    'regular',
#    'safety',
#    'level',
#    'model.',
#    'node',
#    'guaranteed',
#    'node',
#    'defined',
#    'terms',
#    'directed',
#    'safety',
#    'levels',
#    'associated',
#    'The',
#    'directed',
#    'safety',
#    'level',
#    'model',
#    '=',
#    '1',
#    '=',
#    '2',
#    'complexity',
#    'regular',
#    'safety',
#    'level',
#    'model.',
#    'Simulation',
#    'results',
#    'show',
#    'significant',
#    'improvement',
#    'terms',
#    'optimal',
#    'broadcast',
#    'capability']},
#  {'quoted': [],
#   'title': 'A Compiler Framework for Supporting Speculative Multicore Processors.',
#   'authors': 'Pen-Chung Yew',
#   'date': '2007',
#   'source': 'Asia-Pacific Computer Systems Architecture Conference',
#   'index': '11438',
#   'abstract': ['As',
#    'technology',
#    'currently',
#    'computer',
#    'industry',
#    'power',
#    'consumption',
#    'improve',
#    'performance',
#    'improvement',
#    'single',
#    'application',
#    'systems',
#    'remains',
#    'important',
#    'challenging',
#    'on-chip',
#    'communication',
#    'latency',
#    'using',
#    'parallelism',
#    'improve',
#    'number',
#    'per',
#    'clock',
#    'i.e.,',
#    'improve',
#    'performance,',
#    'shown',
#    'effective',
#    'many',
#    'applications.',
#    'However,',
#    'program',
#    'characteristics',
#    'applications,',
#    'effective',
#    'schemes']},
#  {'quoted': [],
#   'title': 'Self-Emergence of Structures in Gene Expression Programming.',
#   'authors': 'Xin Li',
#   'date': '2005',
#   'source': 'AAAI',
#   'index': '11954',
#   'abstract': ['This',
#    'work',
#    'improving',
#    'problem',
#    'solving',
#    'ability',
#    'algorithm',
#    'complex',
#    'data',
#    'mining',
#    'tasks',
#    'structures',
#    'process.',
#    'The',
#    'main',
#    'include',
#    'constant',
#    'techniques',
#    'good',
#    'functional',
#    'structures',
#    'analysis',
#    'current',
#    'implementation',
#    'scheme',
#    'novel',
#    'structures',
#    'achieve',
#    'flexible',
#    'search',
#    'process',
#    'solutions',
#    'higher']},
#  {'quoted': ['12360',
#    '621238',
#    '1060979',
#    '592653',
#    '1061077',
#    '673999',
#    '268210',
#    '14491'],
#   'title': 'Computing Slater Rankings Using Similarities among Candidates.',
#   'authors': 'Vincent Conitzer',
#   'date': '2006',
#   'source': 'AAAI',
#   'index': '12356',
#   'abstract': ['(or',
#    'general',
#    'method',
#    'preferences',
#    'multiple',
#    'agents.',
#    'One',
#    'important',
#    'rule',
#    'It',
#    'ranking',
#    '(or',
#    'minimize',
#    'number',
#    'pairs',
#    'ranking',
#    'two',
#    'The',
#    'use',
#    'rule',
#    'lack',
#    'techniques',
#    'compute',
#    'In',
#    'paper,',
#    'show',
#    'problem',
#    'smaller',
#    'set',
#    'similar',
#    'We',
#    'show',
#    'technique',
#    'compute',
#    'ranking',
#    'linear',
#    'time',
#    'graph',
#    'For',
#    'general',
#    'case,',
#    'also',
#    'give',
#    'efficient',
#    'algorithm',
#    'finding',
#    'set',
#    'similar',
#    'We',
#    'provide',
#    'experimental',
#    'results',
#    'show',
#    'technique',
#    'significantly',
#    'search',
#    'algorithms,',
#    'Finally,',
#    'also',
#    'use',
#    'technique',
#    'similar',
#    'sets',
#    'show',
#    'computing',
#    'optimal',
#    'ranking',
#    'even']},
#  {'quoted': ['2020', '951331'],
#   'title': 'Complexity of Manipulating Elections with Few Candidates.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2002',
#   'source': 'AAAI/IAAI',
#   'index': '12359',
#   'abstract': ['In',
#    'multiagent',
#    'agents',
#    'different',
#    'aggregation',
#    'central',
#    'general',
#    'method',
#    'results',
#    'shown',
#    'general',
#    'protocols',
#    'One',
#    'could',
#    'avoid',
#    'manipulation',
#    'using',
#    'protocols',
#    'determining',
#    'manipulation',
#    'among',
#    'computational',
#    'reasonable',
#    'measure',
#    'computational',
#    'Some',
#    'earlier',
#    'work',
#    'done',
#    'number',
#    'We',
#    'derive',
#    'results',
#    'common',
#    'setting',
#    'number',
#    'small',
#    'number',
#    'We',
#    'show',
#    'complete',
#    'information',
#    'individual',
#    'manipulation',
#    'manipulation',
#    'easy',
#    'However,',
#    'manipulation',
#    'weighted',
#    'protocols',
#    'manipulation',
#    'protocols',
#    'used',
#    'make',
#    'manipulation',
#    'Finally,',
#    'show',
#    'weak',
#    'weighted',
#    'manipulation',
#    'complete',
#    'information',
#    'hard',
#    'individual',
#    'manipulation',
#    'hard',
#    'uncertainty']},
#  {'quoted': ['12222', '12359', '745321'],
#   'title': 'Vote Elicitation: Complexity and Strategy-Proofness.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2002',
#   'source': 'AAAI/IAAI',
#   'index': '12360',
#   'abstract': ['central',
#    'problem',
#    'received',
#    'significant',
#    'attention',
#    'It',
#    'also',
#    'key',
#    'problem',
#    'multiagent',
#    'systems,',
#    'received',
#    'little',
#    'attention',
#    'In',
#    'agents',
#    'may',
#    'different',
#    'preferences',
#    'often',
#    'must',
#    'using',
#    'This',
#    'leads',
#    'interesting',
#    'issues',
#    'information',
#    'agent',
#    'depends',
#    'agents',
#    'preferences',
#    'In',
#    'paper',
#    'study',
#    'effective',
#    'common',
#    'It',
#    'even',
#    'easy',
#    'protocols',
#    'determining',
#    'effectively',
#    'even',
#    'agents',
#    'The',
#    'protocol',
#    'effective',
#    'We',
#    'also',
#    'show',
#    'introduces',
#    'additional',
#    'opportunities',
#    'manipulation',
#    'We',
#    'demonstrate',
#    'space',
#    'schemes',
#    'additional',
#    'issues']},
#  {'quoted': ['12359', '610600', '13470', '745799', '15640'],
#   'title': 'Computing Shapley Values, Manipulating Value Division Schemes, and Checking Core Membership in Multi-Issue Domains.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2004',
#   'source': 'AAAI',
#   'index': '12361',
#   'abstract': ['key',
#    'problem',
#    'automated',
#    'among',
#    'agents.',
#    'In',
#    'order',
#    'key',
#    'question',
#    'must',
#    'solution',
#    'concepts',
#    'computational',
#    'questions',
#    'around',
#    'solution',
#    'concepts',
#    'received',
#    'little',
#    'We',
#    'study',
#    'representation',
#    'functions',
#    'allows',
#    'agents',
#    'number',
#    'independent',
#    'issues',
#    'agents',
#    'For',
#    'example,',
#    'may',
#    'set',
#    'tasks',
#    'agents',
#    'could',
#    'task',
#    'generates',
#    'certain',
#    'amount',
#    'value',
#    'well',
#    'task',
#    'Given',
#    'show',
#    'quickly',
#    'compute',
#    'value',
#    'scheme',
#    'certain',
#    'We',
#    'show',
#    'based',
#    'value',
#    'known',
#    'manipulation',
#    'order',
#    'agents',
#    'manipulation',
#    'Thus,',
#    'computational',
#    'complexity',
#    'Finally,',
#    'show',
#    'given',
#    'value',
#    'determining',
#    'whether',
#    'case',
#    'computational',
#    'complexity',
#    'increase']},
#  {'quoted': ['1493705',
#    '592816',
#    '971894',
#    '745797',
#    '56621',
#    '609859',
#    '626768',
#    '592644'],
#   'title': 'Expressive Negotiation in Settings with Externalities.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2005',
#   'source': 'AAAI',
#   'index': '12362',
#   'abstract': ['In',
#    'recent',
#    'years,',
#    'certain',
#    'combinatorial',
#    'combinatorial',
#    'become',
#    'important',
#    'research',
#    'topic',
#    'AI',
#    'community.',
#    'A',
#    'assumption',
#    'agents',
#    'variable',
#    'whether',
#    'takes',
#    'place',
#    'variable',
#    'set.',
#    'To',
#    'widely',
#    'studied',
#    'combinatorial',
#    'In',
#    'paper,',
#    'introduce',
#    'We',
#    'show',
#    'number',
#    'key',
#    'special',
#    'cases,',
#    'find',
#    'solution',
#    '(and',
#    'therefore',
#    'maximum',
#    'social',
#    'However,',
#    'one',
#    'important',
#    'special',
#    'case,',
#    'give',
#    'algorithm',
#    'solution',
#    'agent',
#    'linear',
#    'number',
#    'utility',
#    'functions',
#    'constant',
#    'social',
#    'however,',
#    'remains',
#    'even',
#    'We',
#    'also',
#    'demonstrate',
#    'special',
#    'case',
#    'solved',
#    'polynomial',
#    'time',
#    'linear']},
#  {'quoted': ['632435', '592841', '56407', '211744', '268834', '592763'],
#   'title': 'A Generalized Strategy Eliminability Criterion and Computational Methods for Applying It.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2005',
#   'source': 'AAAI',
#   'index': '12363',
#   'abstract': ['We',
#    'define',
#    'generalized',
#    'strategy',
#    'games',
#    'considers',
#    'whether',
#    'given',
#    'strategy',
#    'relative',
#    'given',
#    '&',
#    'subsets',
#    'We',
#    'show',
#    'definition',
#    'criteria',
#    'sets',
#    'small',
#    'Nash',
#    'equilibrium',
#    'sets',
# ...
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': ['1492367',
#    '211093',
#    '588601',
#    '622808',
#    '621965',
#    '972738',
#    '622864',
#    '632883',
#    '622706',
#    '211677'],
#   'title': 'Algorithms, Games, and the Internet.',
#   'authors': 'Christos H. Papadimitriou',
#   'date': '2001',
#   'source': 'ICALP',
#   'index': '268834',
#   'abstract': ['If',
#    'Internet',
#    'next',
#    'great',
#    'subject',
#    'Computer',
#    'model',
#    'likely',
#    'prove',
#    'useful',
#    'In',
#    'talk',
#    'I',
#    'survey',
#    'opportunities',
#    'challenges',
#    'important']},
#  {'quoted': [],
#   'title': 'The VLSI Revolution in Theoretical Circles.',
#   'authors': 'Arnold L. Rosenberg',
#   'date': '1984',
#   'source': 'ICALP',
#   'index': '268934',
#   'abstract': ['pages',
#    'personal',
#    'effect',
#    'circuit',
#    'technology',
#    'Computer',
#    'field',
#    'together',
#    'much',
#    'effect',
#    'earlier',
#    'The',
#    'includes',
#    'well',
#    'theoretical']},
#  {'quoted': [],
#   'title': 'Quick k-Median, k-Center, and Facility Location for Sparse Graphs.',
#   'authors': 'Mikkel Thorup',
#   'date': '2001',
#   'source': 'ICALP',
#   'index': '269122',
#   'abstract': ['We',
#    'present',
#    'time',
#    'space',
#    'constant',
#    'factor',
#    'approximation',
#    'algorithms',
#    'location',
#    'problems',
#    'assignment',
#    'costs',
#    'shortest',
#    'path',
#    'weighted',
#    'graph',
#    'n',
#    'vertices',
#    'For',
#    'location',
#    'problems,',
#    'time',
#    'space',
#    'algorithms',
#    'already',
#    'addressing',
#    'large',
#    'sparse',
#    'graphs.',
#    'An',
#    'application',
#    'could',
#    'content',
#    'The',
#    'Internet',
#    'large',
#    'changes',
#    'time',
#    'solution',
#    'would',
#    'likely',
#    'long']},
#  {'quoted': [],
#   'title': 'Credentials-Based Authorization: Evaluation and Implementation.',
#   'authors': 'Fred B. Schneider',
#   'date': '2007',
#   'source': 'ICALP',
#   'index': '269198',
#   'abstract': ['new',
#    'operating',
#    'system',
#    'runs',
#    'computers',
#    'secure',
#    'designed',
#    'support',
#    'construction',
#    'actions',
#    'measure',
#    'trust',
#    'assumptions']},
#  {'quoted': [],
#   'title': 'Ushering in a New Era of Algorithm Design.',
#   'authors': 'Bernard Chazelle',
#   'date': '2007',
#   'source': 'ICALP',
#   'index': '269250',
#   'abstract': ['data',
#    'together',
#    'basic',
#    'algorithm',
#    'design',
#    'Computing',
#    'data',
#    'data',
#    'property',
#    'algorithms',
#    'parts',
#    'growing',
#    'using',
#    'algorithms',
#    'modeling',
#    'tools',
#    'natural',
#    'I',
#    'discuss',
#    'particular,',
#    'algorithms,',
#    'online',
#    'algorithms.']},
#  {'quoted': ['836397', '610603', '839403'],
#   'title': 'On the Approximability of Average Completion Time Scheduling under Precedence Constraints.',
#   'authors': 'Gerhard J. Woeginger',
#   'date': '2001',
#   'source': 'ICALP',
#   'index': '269259',
#   'abstract': ['We',
#    'consider',
#    'scheduling',
#    'problem',
#    'minimizing',
#    'average',
#    'weighted',
#    'job',
#    'time',
#    'single',
#    'machine',
#    'constraints.',
#    'We',
#    'show',
#    'problem',
#    'arbitrary',
#    'job',
#    'special',
#    'case',
#    'problem',
#    'job',
#    'weights',
#    'several',
#    'special',
#    'cases',
#    'problem',
#    'threshold',
#    'respect',
#    'polynomial',
#    'time',
#    'approximation',
#    'algorithms.',
#    'Moreover,',
#    'special',
#    'case',
#    'order',
#    'constraints',
#    'special',
#    'case',
#    'convex',
#    'give',
#    'polynomial',
#    'time',
#    'approximation',
#    'algorithm',
#    'worst',
#    'case',
#    'performance',
#    'guarantee',
#    'close',
#    'ratio',
#    '+']},
#  {'quoted': [],
#   'title': 'Internet Ad Auctions: Insights and Directions.',
#   'authors': 'S. Muthukrishnan',
#   'date': '2008',
#   'source': 'ICALP (1)',
#   'index': '269362',
#   'abstract': ['On',
#    'different',
#    'video',
#    'objects',
#    'underlying',
#    'content',
#    'There',
#    'industry',
#    'behind',
#    'management',
#    'face',
#    'number',
#    'algorithmic',
#    'This',
#    'present',
#    'small',
#    'selection',
#    'problems,',
#    'open',
#    'research',
#    'The',
#    'ACM',
#    'Portal',
#    'published',
#    'Association',
#    'Computing',
#    'Machinery.',
#    'Copyright',
#    '©',
#    '2010',
#    'ACM,',
#    'Inc.',
#    'Terms',
#    'Usage',
#    'Privacy',
#    'Policy',
#    'Code',
#    'Ethics',
#    'Contact',
#    'Us',
#    'Useful',
#    'downloads:',
#    'Adobe',
#    'Acrobat',
#    'QuickTime',
#    'Windows',
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': [],
#   'title': 'A Model of Facial Expression for 3D Avatar.',
#   'authors': 'Zhen Liu',
#   'date': '2007',
#   'source': 'International Conference on Computational Science (3)',
#   'index': '280794',
#   'abstract': ['3D',
#    'useful',
#    '3D',
#    'complex',
#    'construct',
#    'complex',
#    'expression',
#    'interesting',
#    'The',
#    'concept',
#    'vector',
#    'presented.',
#    'state',
#    '3D',
#    'vector',
#    'basic',
#    'The',
#    'concept',
#    'expression',
#    'vector',
#    'expression',
#    'expression',
#    'vector',
#    'basic',
#    'expression',
#    'mapping',
#    'set',
#    'vector',
#    'space',
#    'expression',
#    'vector',
#    'space.',
#    'A',
#    'carried']},
#  {'quoted': ['283339', '286764', '283391', '283159', '1080991', '133790'],
#   'title': "Compatible Observability Don't Cares Revisited.",
#   'authors': 'Robert K. Brayton',
#   'date': '2001',
#   'source': 'ICCAD',
#   'index': '281764',
#   'abstract': ['We',
#    'first',
#    'examine',
#    'definition',
#    'set',
#    'We',
#    'discuss',
#    'computation',
#    'output',
#    'show',
#    'example,',
#    'results',
#    'current',
#    'implementation',
#    'computation',
#    'result',
#    'independent',
#    'implementation',
#    'The',
#    'computation',
#    'proved',
#    'primary',
#    'inputs',
#    'local',
#    'combine',
#    'part',
#    'network.',
#    'form',
#    'local',
#    'parts',
#    'network.',
#    'Both',
#    'shown',
#    'We',
#    'give',
#    'method',
#    'kinds',
#    'local',
#    'nodes',
#    'network']},
#  {'quoted': ['950469', '455109', '456064'],
#   'title': 'Test scheduling for core-based systems.',
#   'authors': 'Krishnendu Chakrabarty',
#   'date': '1999',
#   'source': 'ICCAD',
#   'index': '281814',
#   'abstract': ['We',
#    'present',
#    'optimal',
#    'solutions',
#    'test',
#    'scheduling',
#    'problem',
#    'systems.',
#    'We',
#    'show',
#    'test',
#    'scheduling',
#    'equivalent',
#    'scheduling',
#    'problem',
#    'therefore',
#    'However,',
#    'problem',
#    '=',
#    'solved',
#    'polynomial',
#    'time.',
#    'For',
#    'general',
#    'case',
#    '>',
#    'present',
#    'linear',
#    'programming',
#    'model',
#    'optimal',
#    'scheduling',
#    'apply',
#    'representative',
#    'system',
#    'using',
#    'We',
#    'also',
#    'extend',
#    'model',
#    'allow',
#    'optimal',
#    'test',
#    'set',
#    'selection',
#    'set',
#    'Finally,',
#    'present',
#    'efficient',
#    'heuristic',
#    'algorithm',
#    'larger',
#    'systems',
#    'model',
#    'may']},
#  {'quoted': ['454599', '454423', '454256'],
#   'title': 'RAFT191486: a novel program for rapid-fire test and diagnosis of digital logic for marginal delays and delay faults.',
#   'authors': 'Abhijit Chatterjee,Jacob A. Abraham',
#   'date': '1994',
#   'source': 'ICCAD',
#   'index': '281892',
#   'abstract': ['The',
#    'problem',
#    'delay',
#    'detection',
#    'performance',
#    'become',
#    'even',
#    'critical',
#    'due',
#    'clock',
#    'In',
#    'paper,',
#    'methodology',
#    'detection',
#    'digital',
#    'circuits',
#    'diagnosis',
#    'delay',
#    'failures',
#    'A',
#    'new',
#    'test',
#    'application',
#    'methodology',
#    'proposed',
#    'test',
#    'vectors',
#    'may',
#    'applied',
#    'digital',
#    'combinational',
#    'circuits',
#    'smaller',
#    'critical',
#    'path',
#    'delay',
#    'circuit',
#    'signal',
#    'analysis',
#    'used',
#    'test',
#    'results.',
#    'The',
#    'resulting',
#    'tests',
#    'called',
#    '(for',
#    'allow',
#    'classification',
#    'circuits',
#    'along',
#    'continuous']},
#  {'quoted': [],
#   'title': 'Test generation for delay faults in non-scan and partial scan sequential circuits.',
#   'authors': 'Kwang-Ting Cheng',
#   'date': '1992',
#   'source': 'ICCAD',
#   'index': '281900',
#   'abstract': ['A',
#    'recently',
#    'proposed',
#    'transition',
#    'fault',
#    'model',
#    'sequential',
#    'circuits',
#    'considered.',
#    'In',
#    'fault',
#    'model,',
#    'transition',
#    'fault',
#    'fault',
#    'fault',
#    'type',
#    'fault',
#    'It',
#    'observed',
#    'comprehensive',
#    'functional',
#    'verification',
#    'sequence',
#    'sequence',
#    'high',
#    'stuck-at',
#    'fault',
#    'coverage',
#    'gives',
#    'high',
#    'transition',
#    'fault',
#    'coverage',
#    'sequential',
#    'circuits.',
#    'test',
#    'generation',
#    'delay',
#    'faults',
#    'required',
#    'coverage',
#    'reasonable',
#    'test',
#    'generation',
#    'algorithm',
#    'fault',
#    'model',
#    'presented.',
#    'With',
#    'use',
#    'fault',
#    'tests',
#    'transition',
#    'faults',
#    'generated',
#    'using',
#    'stuck-at',
#    'fault',
#    'test',
#    'generation',
#    'algorithm',
#    'The',
#    'test',
#    'integrated',
#    'sequential',
#    'circuit',
#    'delay',
#    'fault',
#    'Experimental',
#    'results',
#    'benchmark',
#    'circuits',
#    'designs',
#    'presented.',
#    'For',
#    'partial',
#    'scan',
#    'test',
#    'application',
#    'scheme',
#    'detecting',
#    'transition',
#    'faults',
#    'described.',
#    'test',
#    'generation',
#    'fault',
#    'simulation',
#    'algorithms',
#    'required',
#    'partial',
#    'scan',
#    'circuits',
#    'presented.',
#    'Experimental',
#    'results',
#    'presented']},
#  {'quoted': ['133192', '281974', '131860', '133770'],
#   'title': 'Optimal wiresizing for interconnects with multiple sources.',
#   'authors': 'Jason Cong,Lei He',
#   'date': '1995',
#   'source': 'ICCAD',
#   'index': '281970',
#   'abstract': ['The',
#    'optimal',
#    'problem',
#    'multiple',
#    'sources',
#    'studied',
#    'distributed',
#    'delay',
#    'model.',
#    'We',
#    'source',
#    'set',
#    'show',
#    'optimal',
#    'solution',
#    'satisfies',
#    'number',
#    'interesting',
#    'local',
#    'property',
#    'general',
#    'Furthermore,',
#    'study',
#    'optimal',
#    'problem',
#    'using',
#    'variable',
#    'grid',
#    'These',
#    'properties',
#    'lead',
#    'efficient',
#    'algorithms',
#    'compute',
#    'lower',
#    'upper',
#    'bounds',
#    'optimal',
#    'results',
#    'processor',
#    'show',
#    'delay',
#    'reduction',
#    'compared',
#    'In',
#    'addition,',
#    'algorithm',
#    'based',
#    'variable',
#    'grid',
#    'yields',
#    'two',
#    'without',
#    'loss',
#    'compared',
#    'fixed',
#    'grid',
#    'based',
#    'methods.']},
#  {'quoted': ['282899',
#    '283470',
#    '281865',
#    '282601',
#    '131707',
#    '194016',
#    '281974',
#    '436652',
#    '131860',
#    '133770',
#    '282723'],
#   'title': 'An efficient approach to simultaneous transistor and interconnect sizing.',
#   'authors': 'Jason Cong,Lei He',
#   'date': '1996',
#   'source': 'ICCAD',
#   'index': '281971',
#   'abstract': ['In',
#    'paper,',
#    'study',
#    'problem.',
#    'We',
#    'define',
#    'class',
#    'optimization',
#    'problems',
#    'programs',
#    'general',
#    'property',
#    'programs.',
#    'We',
#    'show',
#    'problems',
#    'number',
#    'delay',
#    'models',
#    'programs',
#    'propose',
#    'efficient',
#    'algorithm',
#    'based',
#    'When',
#    'used',
#    'solve',
#    'problem',
#    'real',
#    'reduces',
#    'maximum',
#    'delay',
#    'reduces',
#    'power',
#    'consumption',
#    'factor',
#    'compared',
#    'original',
#    'When',
#    'used',
#    'solve',
#    'problem,',
#    'achieves',
#    'Moreover,',
#    'algorithm',
#    'clock']},
#  {'quoted': [],
#   'title': 'Simultaneous driver and wire sizing for performance and power optimization.',
#   'authors': 'Jason Cong,Cheng-Kok Koh',
#   'date': '1994',
#   'source': 'ICCAD',
#   'index': '281974',
#   'abstract': ['In',
#    'paper,',
#    'study',
#    'problem',
#    'two',
#    'objective',
#    'delay',
#    'combined',
#    'delay',
#    'power',
#    'We',
#    'present',
#    'general',
#    'problem',
#    'two',
#    'based',
#    'distributed',
#    'delay',
#    'model',
#    'power',
#    'power',
#    'We',
#    'show',
#    'several',
#    'interesting',
#    'properties',
#    'optimal',
#    'solutions',
#    'two',
#    'including',
#    'important',
#    'result',
#    'relationship',
#    'optimal',
#    'These',
#    'results',
#    'lead',
#    'polynomial',
#    'time',
#    'algorithms',
#    'computing',
#    'lower',
#    'upper',
#    'bounds',
#    'optimal',
#    'solutions',
#    'two',
#    'efficient',
#    'algorithms',
#    'computing',
#    'optimal',
#    'solutions',
#    'two',
#    'We',
#    'implemented',
#    'algorithms',
#    'compared',
#    'existing',
#    'design',
#    'methods',
#    'independent',
#    'simulations',
#    'shows',
#    'methods',
#    'reduce',
#    'delay',
#    'power',
#    'compared',
#    'existing',
#    'design',
#    'methods.']},
#  {'quoted': ['282899',
#    '131708',
#    '282601',
#    '1134461',
#    '132443',
#    '926961',
#    '282211',
#    '132974',
#    '132762',
#    '132238',
#    '131860',
#    '1078390'],
#   'title': 'Interconnect layout optimization under higher-order RLC model.',
#   'authors': 'Jason Cong,Cheng-Kok Koh',
#   'date': '1997',
#   'source': 'ICCAD',
#   'index': '281975',
#   'abstract': ['optimization',
#    'problem',
#    'model',
#    'delay',
#    'also',
#    'circuits',
#    'signal',
#    'We',
#    'propose',
#    'approach',
#    'considers',
#    'optimization',
#    'optimization',
#    'Our',
#    'algorithm',
#    'considers',
#    'large',
#    'class',
#    'routing',
#    'trees',
#    'trees',
#    'We',
#    'construct',
#    'set',
#    'providing',
#    'among',
#    'signal',
#    'routing',
#    'Using',
#    'new',
#    'computation',
#    'algorithm,',
#    'construction',
#    'computation',
#    'facilitate',
#    'accurate',
#    'delay',
#    'evaluation',
#    'Experimental',
#    'results',
#    'show',
#    'algorithm',
#    'able',
#    'construct',
#    'set',
#    'providing',
#    'among',
#    'signal',
#    'signal',
#    'time,',
#    'routing']},
#  {'quoted': ['281914',
#    '282179',
#    '131807',
#    '281988',
#    '52186',
#    '446438',
#    '132448'],
#   'title': 'Thermal via planning for 3-D ICs.',
#   'authors': 'Jason Cong,Yan Zhang',
#   'date': '2005',
#   'source': 'ICCAD',
#   'index': '281991',
#   'abstract': ['one',
#    'challenges',
#    'One',
#    'effective',
#    'way',
#    'reducing',
#    'circuit',
#    'introduce',
#    'In',
#    'paper,',
#    'extended',
#    'planning',
#    'routing',
#    'framework',
#    'use',
#    'much',
#    'planning',
#    'algorithm.',
#    'We',
#    'problem',
#    'constraints',
#    'nonlinear',
#    'programming',
#    'problem',
#    'based',
#    'model',
#    'develop',
#    'efficient',
#    'heuristic',
#    'algorithm,',
#    'named',
#    'sequence',
#    'via',
#    'planning',
#    'The',
#    'via',
#    'distribution',
#    'convex',
#    'programming',
#    'problem,',
#    'via',
#    'planning',
#    'based',
#    'two',
#    'efficient',
#    'path',
#    'Experimental',
#    'results',
#    'show',
#    'algorithm',
#    'faster',
#    'direct',
#    'solution',
#    'via',
#    'planning',
#    'similar',
#    'solution',
#    'quality',
#    'However,',
#    'compared',
#    'recent',
#    'work',
#    'planning',
#    'algorithm',
#    'based',
#    'algorithm',
#    'reduce',
#    'total',
#    'number',
#    'required',
#    'similar']},
#  {'quoted': ['131769',
#    '132889',
#    '285892',
#    '453622',
#    '453623',
#    '282053',
#    '454132',
#    '282233',
#    '282869',
#    '455159',
#    '858422',
#    '1078626',
#    '286764'],
#   'title': 'Non-scan design-for-testability of RT-level data paths.',
#   'authors': 'Sujit Dey,Miodrag Potkonjak',
#   'date': '1994',
#   'source': 'ICCAD',
#   'index': '282051',
#   'abstract': ['This',
#    'paper',
#    'presents',
#    'technique',
#    'applicable',
#    'level',
#    'data',
#    'path',
#    'usually',
#    'due',
#    'presence',
#    'complex',
#    'loop',
#    'We',
#    'develop',
#    'new',
#    'structure',
#    'data',
#    'circuit',
#    'make',
#    'easily',
#    'without',
#    'either',
#    'scan',
#    'The',
#    'technique',
#    'applied',
#    'several',
#    'data',
#    'path',
#    'circuits.',
#    'Experimental',
#    'results',
#    'demonstrate',
#    'data',
#    'The',
#    'hardware',
#    'overhead',
#    'test',
#    'application',
#    'time',
#    'required',
#    'designs',
#    'significantly',
#    'lower',
#    'corresponding',
#    'partial',
#    'scan']},
#  ...]

# %%
def update_quoted_by(articles):
    all_indexes = set()
    for article in articles:
        all_indexes.add(article['index'])
    articles_copy = copy.deepcopy(articles)
    for article in articles_copy:
        updated_quoted = [quoted for quoted in article['quoted'] if quoted in all_indexes]
        article['quoted'] = updated_quoted
    return articles_copy
        
    
update_quoted_by(filtered_articles_with_frequent_words)
# Out:
# [{'quoted': [],
#   'title': 'Spatial Data Structures.',
#   'authors': 'Hanan Samet',
#   'date': '1995',
#   'source': 'Modern Database Systems',
#   'index': '25',
#   'abstract': ['An',
#    'overview',
#    'presented',
#    'use',
#    'spatial',
#    'data',
#    'structures',
#    'spatial',
#    'databases.',
#    'The',
#    'focus',
#    'hierarchical',
#    'data',
#    'including',
#    'number',
#    'data',
#    'respect',
#    'space',
#    'it.',
#    'Such',
#    'techniques',
#    'known',
#    'spatial',
#    'indexing',
#    'methods.',
#    'data',
#    'structures',
#    'based',
#    'recursive',
#    'They',
#    'nature',
#    'data',
#    'space',
#    'well',
#    'time',
#    'also',
#    'facilitate',
#    'operations',
#    'given',
#    'use',
#    'data',
#    'structures',
#    'representation',
#    'different',
#    'data',
#    'types']},
#  {'quoted': [],
#   'title': 'ACTA: The SAGA Continues',
#   'authors': 'Panos K. Chrysanthis,Krithi Ramamritham',
#   'date': '1992',
#   'source': 'Database Transaction Models for Advanced Applications',
#   'index': '2194',
#   'abstract': ['comprehensive',
#    'transaction',
#    'framework',
#    'transaction',
#    'effects',
#    'extended',
#    'transactions',
#    'objects',
#    'allows',
#    'specification',
#    '(1)',
#    'interactions',
#    'transactions',
#    'terms',
#    'relationships',
#    'significant',
#    'different',
#    'transactions',
#    '(2)',
#    'effects',
#    'state',
#    '(i.e.,',
#    'synchronization',
#    'extended',
#    'traditional',
#    'models',
#    'proposed',
#    'deal',
#    'involve',
#    'collaborative',
#    'One',
#    'model',
#    'independent',
#    'transactions',
#    'way',
#    'component',
#    'actions',
#    'even',
#    'However,',
#    'effects',
#    'components',
#    'After',
#    'giving',
#    'modeling',
#    'illustrate',
#    'use',
#    'giving',
#    'complete',
#    'formal',
#    'characterization',
#    'reasoning',
#    'power',
#    'shown',
#    'proving',
#    'properties',
#    'Finally,',
#    'series',
#    'variations',
#    'original',
#    'model',
#    'changes',
#    'formal',
#    'characterization']},
#  {'quoted': [],
#   'title': 'Optimizing Datalog Programs.',
#   'authors': 'Yehoshua Sagiv',
#   'date': '1988',
#   'source': 'Foundations of Deductive Databases and Logic Programming.',
#   'index': '2261',
#   'abstract': ['programs,',
#    'i.e.,',
#    'programs',
#    'without',
#    'function',
#    'considered',
#    'It',
#    'variable',
#    'rule',
#    'must',
#    'also',
#    'appear',
#    'The',
#    'input',
#    'program',
#    'set',
#    'given',
#    'addition',
#    'and,',
#    'viewed',
#    'assignment',
#    'relations',
#    'Two',
#    'programs',
#    'equivalent',
#    'produce',
#    'result',
#    'possible',
#    'relations',
#    '(i.e.,',
#    'appear',
#    'Two',
#    'programs',
#    'equivalent',
#    'produce',
#    'result',
#    'possible',
#    'initial',
#    'relations',
#    '(i.e.,',
#    'The',
#    'equivalence',
#    'problem',
#    'programs',
#    'known',
#    'It',
#    'shown',
#    'uniform',
#    'equivalence',
#    'algorithm',
#    'given',
#    'minimizing',
#    'program',
#    'uniform',
#    'A',
#    'technique',
#    'parts',
#    'program',
#    'redundant',
#    'equivalence',
#    'uniform',
#    'A',
#    'procedure',
#    'testing',
#    'uniform',
#    'equivalence',
#    'also',
#    'developed',
#    'case',
#    'database',
#    'satisfies',
#    'constraints.']},
#  {'quoted': [],
#   'title': 'Distributed Algorithms',
#   'authors': 'Nancy A. Lynch',
#   'date': '1996',
#   'index': '2339',
#   'abstract': ['provides',
#    'analyzing',
#    'distributed',
#    'algorithms.',
#    'book',
#    'wide',
#    'including',
#    'system',
#    'designers',
#    'contains',
#    'significant',
#    'algorithms',
#    'results',
#    'simple',
#    'The',
#    'algorithms',
#    'proved',
#    'complexity',
#    'analyzed',
#    'according',
#    'defined',
#    'complexity',
#    'The',
#    'problems',
#    'include',
#    'resource',
#    'among',
#    'distributed',
#    'data',
#    'global',
#    'many',
#    'The',
#    'according',
#    'system',
#    'model',
#    '-',
#    'first',
#    'timing',
#    'model',
#    'communication',
#    'The',
#    'system',
#    'models',
#    'separate',
#    'easy',
#    'The',
#    'presentation',
#    'yet',
#    'enough',
#    'This',
#    'book',
#    'important',
#    'problems,',
#    'algorithms,',
#    'results',
#    'problems',
#    'arise',
#    'apply',
#    'algorithms',
#    'solve',
#    'use',
#    'results',
#    'determine',
#    'whether',
#    'problems',
#    'The',
#    'book',
#    'also',
#    'provides',
#    'basic',
#    'mathematical',
#    'tools',
#    'designing',
#    'new',
#    'algorithms',
#    'proving',
#    'new',
#    'results.',
#    'In',
#    'addition,',
#    'reason',
#    'distributed',
#    'algorithms',
#    '-',
#    'model',
#    'required',
#    'prove',
#    'evaluate',
#    'performance',
#    'realistic']},
#  {'quoted': [],
#   'title': 'Signature Files.',
#   'authors': 'Christos Faloutsos',
#   'date': '1992',
#   'source': 'Information Retrieval: Data Structures & Algorithms',
#   'index': '2518',
#   'abstract': ['The',
#    'provide',
#    'students',
#    'working',
#    'area',
#    'computing',
#    'present',
#    'discuss',
#    'research',
#    'approaches',
#    'results.',
#    'The',
#    'around',
#    'conference',
#    'selected',
#    'research',
#    'presented.']},
#  {'quoted': ['598255', '1118151', '1064571'],
#   'title': 'Concurrency Control Performance Modeling: Alternatives and Implications.',
#   'authors': 'Rakesh Agrawal,Michael J. Carey,Miron Livny',
#   'date': '1996',
#   'source': 'Performance of Concurrency Control Mechanisms in Centralized Database Systems',
#   'index': '2548',
#   'abstract': ['A',
#    'number',
#    'recent',
#    'studies',
#    'performance',
#    'concurrency',
#    'control',
#    'algorithms',
#    'database',
#    'management',
#    'systems.',
#    'The',
#    'results',
#    'rather',
#    'In',
#    'paper,',
#    'rather',
#    'another',
#    'algorithm',
#    'performance',
#    'investigate',
#    'assumptions',
#    'made',
#    'models',
#    'used',
#    'past',
#    'studies',
#    'We',
#    'complete',
#    'model',
#    'database',
#    'environment',
#    'relative',
#    'performance',
#    'three',
#    'different',
#    'approaches',
#    'concurrency',
#    'control',
#    'problem',
#    'variety',
#    'modeling',
#    'The',
#    'three',
#    'approaches',
#    'studied',
#    'represent',
#    'different',
#    'transaction',
#    'assumptions',
#    'nature',
#    'database',
#    'transaction',
#    'amount',
#    'information',
#    'available',
#    'concurrency',
#    'control',
#    'algorithm',
#    'We',
#    'show',
#    'differences',
#    'underlying',
#    'assumptions',
#    'explain',
#    'performance',
#    'results.',
#    'We',
#    'also',
#    'address',
#    'question',
#    'realistic',
#    'various',
#    'assumptions',
#    'actual',
#    'database',
#    'systems.']},
#  {'quoted': [],
#   'title': 'Towards a theory of Recursive Structures.',
#   'authors': 'David Harel',
#   'date': '1995',
#   'source': 'Computer Science Today',
#   'index': '2692',
#   'abstract': ['In',
#    'computer',
#    'one',
#    'mainly',
#    'finite',
#    'objects.',
#    'infinite',
#    'objects',
#    'must',
#    'i.e.,',
#    'thus',
#    'effective',
#    'finite',
#    'This',
#    'leads',
#    'notion',
#    'recursive',
#    'recursive',
#    'structure',
#    'data',
#    'In',
#    'paper',
#    'recent',
#    'work',
#    'recursive',
#    'structures',
#    'data',
#    'including',
#    '(1)',
#    'high',
#    'many',
#    'problems',
#    'recursive',
#    'graphs,',
#    'ways',
#    'results',
#    'classification',
#    'optimization',
#    'problems',
#    'results',
#    'degree',
#    'results',
#    'query',
#    'languages',
#    'recursive',
#    'data',
#    'The',
#    'ACM',
#    'Portal',
#    'published',
#    'Association',
#    'Computing',
#    'Machinery.',
#    'Copyright',
#    '©',
#    '2010',
#    'ACM,',
#    'Inc.',
#    'Terms',
#    'Usage',
#    'Privacy',
#    'Policy',
#    'Code',
#    'Ethics',
#    'Contact',
#    'Us',
#    'Useful',
#    'downloads:',
#    'Adobe',
#    'Acrobat',
#    'QuickTime',
#    'Windows',
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': ['1118705'],
#   'title': 'Object Management in Postgres using Procedures.',
#   'authors': 'Michael Stonebraker',
#   'date': '1991',
#   'source': 'On Object-Oriented Database System',
#   'index': '2804',
#   'abstract': ['This',
#    'paper',
#    'presents',
#    'object',
#    'management',
#    'designed',
#    'data',
#    'This',
#    'system',
#    'unique',
#    'new',
#    'data',
#    'model',
#    'support',
#    'objects',
#    'instead',
#    'extend',
#    'relational',
#    'model',
#    'powerful',
#    'abstract',
#    'data',
#    'capability',
#    'procedures',
#    'data',
#    'base',
#    'objects.',
#    'The',
#    'relational',
#    'model',
#    'paper',
#    'along',
#    'relational']},
#  {'quoted': [],
#   'title': 'Temporally Invariant Junction Tree for Interference in Dynamic Bayesian Network.',
#   'authors': 'Yang Xiang',
#   'date': '1999',
#   'source': 'Artificial Intelligence Today',
#   'index': '3102',
#   'abstract': ['networks',
#    'extend',
#    'networks',
#    'static',
#    'domains',
#    'dynamic',
#    'The',
#    'known',
#    'method',
#    'exact',
#    'inference',
#    'based',
#    'dynamic',
#    'reduction',
#    'active',
#    'It',
#    'effective',
#    'domain',
#    'relatively',
#    'fast',
#    'domain',
#    'inference',
#    'time',
#    'This',
#    'study',
#    'feature',
#    'problem',
#    'domains',
#    'improve',
#    'efficiency',
#    'exact',
#    'inference',
#    'We',
#    'propose',
#    'construction',
#    'directly',
#    'supporting',
#    'exact',
#    'inference',
#    'discuss',
#    'issues',
#    'This',
#    'method',
#    'need',
#    'computation',
#    'associated',
#    'dynamic',
#    'reduction',
#    'existing',
#    'method.',
#    'The',
#    'method',
#    'demonstrated',
#    'experimental']},
#  {'quoted': [],
#   'title': 'Grading Knowledge, Extracting Degree Information from Texts.',
#   'authors': 'Steffen Staab',
#   'date': '1999',
#   'source': 'Lecture Notes in Computer Science',
#   'index': '3551',
#   'abstract': ['natural',
#    'language',
#    'formal',
#    'representation',
#    'text',
#    'knowledge',
#    'methods',
#    'show',
#    'lack',
#    'methods',
#    'understanding',
#    'natural',
#    'language',
#    'like',
#    'hard',
#    'disk',
#    'describe',
#    'properties',
#    'like',
#    'respectively.',
#    'However,',
#    'without',
#    'understanding',
#    'degree',
#    'expressions',
#    'often',
#    'central',
#    'This',
#    'book',
#    'shows',
#    'comprehensive',
#    'concepts',
#    'degree',
#    'information',
#    'natural',
#    'language',
#    'It',
#    'task',
#    'three',
#    'levels',
#    'natural',
#    'language',
#    'degree',
#    'representing',
#    'On',
#    'three',
#    'author',
#    'shows',
#    'approaches',
#    'degree',
#    'understanding',
#    'problem',
#    'since',
#    'large',
#    'role',
#    'knowledge',
#    'Thus,',
#    'gives',
#    'verification',
#    'central',
#    'knowledge',
#    'This',
#    'construction',
#    'First,',
#    'author',
#    'gives',
#    'overview',
#    'information',
#    'system.',
#    'Then,',
#    'review',
#    'relevant',
#    'author',
#    'two',
#    'natural',
#    'language',
#    'degree',
#    'expressions',
#    'proposes',
#    'algorithms',
#    'handle',
#    'system.',
#    'These',
#    'methods',
#    'applied',
#    'two',
#    'text',
#    'medical',
#    'diagnosis',
#    'domain',
#    'information',
#    'Moreover,',
#    'author',
#    'well-known',
#    'constraint',
#    'This',
#    'generalization',
#    'representing',
#    'reasoning',
#    'natural',
#    'language',
#    'degree',
#    'also',
#    'interesting',
#    'point',
#    'view',
#    'field',
#    'temporal',
#    'The',
#    'book',
#    'gives',
#    'integration',
#    'three',
#    'levels',
#    'understanding',
#    'showing',
#    'leads',
#    'even',
#    'advanced',
#    '--',
#    'efficient',
#    '--',
#    'performance',
#    'proposed']},
#  {'quoted': [],
#   'title': 'Web Data Mining: Exploring Hyperlinks, Contents, and Usage Data',
#   'authors': 'Bing Liu',
#   'date': '2007',
#   'source': 'Data-Centric Systems and Applications',
#   'index': '3635',
#   'abstract': ['Web',
#    'mining',
#    'useful',
#    'information',
#    'knowledge',
#    'Web',
#    'page',
#    'data.',
#    'Although',
#    'Web',
#    'mining',
#    'uses',
#    'many',
#    'conventional',
#    'data',
#    'mining',
#    'techniques,',
#    'application',
#    'traditional',
#    'data',
#    'mining',
#    'due',
#    'nature',
#    'Web',
#    'data',
#    'It',
#    'also',
#    'developed',
#    'many',
#    'algorithms',
#    'techniques.',
#    'written',
#    'comprehensive',
#    'text',
#    'Web',
#    'data',
#    'topics',
#    'structure',
#    'mining,',
#    'content',
#    'mining,',
#    'mining',
#    'book',
#    'together',
#    'essential',
#    'concepts',
#    'algorithms',
#    'related',
#    'areas',
#    'data',
#    'mining,',
#    'machine',
#    'text',
#    'processing',
#    'form',
#    'The',
#    'book',
#    'offers',
#    'rich',
#    'theory',
#    'addressing',
#    'research',
#    'well',
#    'technology',
#    'practical',
#    'point',
#    'It',
#    'suitable',
#    'researchers',
#    'Web',
#    'mining',
#    'learning',
#    'text',
#    'use',
#    'classes',
#    'data',
#    'mining,',
#    'Web',
#    'mining,',
#    'Web',
#    'implemented',
#    'algorithms',
#    'available',
#    'The',
#    'ACM',
#    'Portal',
#    'published',
#    'Association',
#    'Computing',
#    'Machinery.',
#    'Copyright',
#    '©',
#    '2010',
#    'ACM,',
#    'Inc.',
#    'Terms',
#    'Usage',
#    'Privacy',
#    'Policy',
#    'Code',
#    'Ethics',
#    'Contact',
#    'Us',
#    'Useful',
#    'downloads:',
#    'Adobe',
#    'Acrobat',
#    'QuickTime',
#    'Windows',
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': [],
#   'title': 'Software Architectures for Task-Oriented Computing.',
#   'authors': 'David Garlan',
#   'date': '2008',
#   'source': 'ACIS-ICIS',
#   'index': '4966',
#   'abstract': ['Recent',
#    'advances',
#    'ubiquitous',
#    'computing,',
#    'computing,',
#    'intelligence',
#    'led',
#    'better',
#    'support',
#    'tasks',
#    'intelligence',
#    'computing',
#    'This',
#    'infrastructure',
#    'computing',
#    'resources',
#    'applications',
#    'one',
#    'hand,',
#    "user's",
#    'high-level',
#    'goals',
#    'In',
#    'talk',
#    'I',
#    'survey',
#    'recent',
#    'research',
#    'developing',
#    'software',
#    'architectures',
#    'support',
#    'new',
#    'features',
#    'architectures',
#    'ability',
#    'interface',
#    'applications,',
#    'still',
#    'considerable',
#    'support',
#    'user',
#    'ability',
#    'machine',
#    'learning',
#    'system',
#    'user',
#    'ability',
#    'resource',
#    'user',
#    'I',
#    'software',
#    'engineering',
#    'challenges',
#    'arise']},
#  {'quoted': [],
#   'title': 'Your way your missions: from location-based to route-based pervasive gaming.',
#   'authors': 'Ling Chen,Steve Benford',
#   'date': '2007',
#   'source': 'Advances in Computer Entertainment Technology',
#   'index': '5113',
#   'abstract': ['In',
#    'paper,',
#    'describe',
#    'design',
#    'implementation',
#    'game',
#    'named',
#    'Since',
#    'game',
#    'play',
#    'game',
#    'without',
#    'changing',
#    'A',
#    'method',
#    'proposed',
#    'obtain',
#    'corresponding',
#    'tool',
#    'developed',
#    'upon',
#    'Two',
#    'approaches',
#    'adaptation',
#    'spatial',
#    'databases',
#    'presented.']},
#  {'quoted': [],
#   'title': 'Metaphorical affect sensing in an intelligent conversational agent.',
#   'authors': 'Li Zhang',
#   'date': '2008',
#   'source': 'Advances in Computer Entertainment Technology',
#   'index': '5393',
#   'abstract': ['We',
#    'report',
#    'new',
#    'developments',
#    'affect',
#    'detection',
#    'component',
#    'processing',
#    'several',
#    'different',
#    'types',
#    'The',
#    'component',
#    'embedded',
#    'intelligent',
#    'AI',
#    'agent',
#    'human',
#    'users',
#    'The',
#    'detected',
#    'states',
#    'also',
#    'play',
#    'important',
#    'role',
#    'affect',
#    'detection',
#    'component',
#    'Our',
#    'work',
#    'conference',
#    'interaction',
#    'based',
#    'affect',
#    'computing,',
#    'learning',
#    'evaluation',
#    'social']},
#  {'quoted': [],
#   'title': 'Making Use: Scenarios and Scenario-Based Design.',
#   'authors': 'John M. Carroll',
#   'date': '2000',
#   'source': 'Symposium on Designing Interactive Systems',
#   'index': '5571',
#   'abstract': ['interaction',
#    'help',
#    'us',
#    'understand',
#    'create',
#    'computer',
#    'systems',
#    'applications',
#    'human',
#    'activity',
#    'human',
#    'activity',
#    'learn',
#    'tools',
#    'use',
#    'work,',
#    'media',
#    'design',
#    'offers',
#    'significant',
#    'unique',
#    'challenges',
#    'design',
#    'content',
#    'design',
#    'work,',
#    'developers',
#    'design',
#    'action',
#    'developers',
#    'design',
#    'multiple',
#    'views',
#    'diverse',
#    'kinds',
#    'developers',
#    'many',
#    'given',
#    'design',
#    'also',
#    'designers',
#    'reuse',
#    'address',
#    'challenge',
#    'technical',
#    'knowledge',
#    'often',
#    'needs',
#    'technical',
#    'design.',
#    'Finally,',
#    'communication',
#    'among',
#    'make',
#    'design',
#    'activities',
#    'great',
#    'variety',
#    'design,',
#    'addressing',
#    'challenge',
#    'often',
#    'attention',
#    'needs',
#    'concerns',
#    'people',
#    'use',
#    'Computer',
#    'He',
#    'written',
#    'technical',
#    'conference',
#    'including',
#    'work',
#    'technology',
#    'system',
#    'development',
#    'Design',
#    'methods',
#    'techniques',
#    'beyond',
#    'The',
#    'design',
#    'interactions']},
#  {'quoted': ['893021'],
#   'title': 'Scenario-based usability engineering.',
#   'authors': 'Mary Beth Rosson,John M. Carroll',
#   'date': '2002',
#   'source': 'Symposium on Designing Interactive Systems',
#   'index': '5711',
#   'abstract': ['This',
#    'tutorial',
#    'introduces',
#    'approach',
#    'engineering',
#    'user',
#    'interaction',
#    'central',
#    'The',
#    'includes',
#    'overview',
#    'group',
#    'analysis',
#    'design',
#    'general']},
#  {'quoted': [],
#   'title': 'E-procurement and market evolution: an evolutionary game approach.',
#   'authors': 'Wei Jiang',
#   'date': '2005',
#   'source': 'ICEC',
#   'index': '5812',
#   'abstract': ['negative',
#    'making',
#    'market',
#    'choice',
#    'online',
#    'game',
#    'paper',
#    'presents',
#    'one',
#    'first',
#    'market',
#    'evolution',
#    'By',
#    'developing',
#    'model,',
#    'addresses',
#    'factors',
#    'market',
#    'basic',
#    'rules',
#    'market',
#    'traditional',
#    'It',
#    'built',
#    'effort',
#    'power',
#    'share',
#    'benefits',
#    'Simulation',
#    'broad',
#    'based',
#    'assumptions',
#    'paper',
#    'initial',
#    'analytical',
#    'basis',
#    'extended',
#    'model',
#    'future',
#    'research.']},
#  {'quoted': [],
#   'title': 'Automated mechanism design: complexity results stemming from the single-agent setting.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2003',
#   'source': 'ICEC',
#   'index': '5943',
#   'abstract': ['The',
#    'aggregation',
#    'preferences',
#    'central',
#    'problem',
#    'multiagent',
#    'systems.',
#    'The',
#    'key',
#    'agents',
#    'may',
#    'report',
#    'preferences',
#    'design',
#    'art',
#    'designing',
#    'rules',
#    'game',
#    'agents',
#    'motivated',
#    'report',
#    'preferences',
#    'desirable',
#    'We',
#    'propose',
#    'approach',
#    'mechanism',
#    'automatically',
#    'created',
#    'aggregation',
#    'setting',
#    'This',
#    'several',
#    'mechanism',
#    'design',
#    'optimization',
#    'problem',
#    'needs',
#    'solved',
#    'time.',
#    'computational',
#    'complexity',
#    'mechanism',
#    'design',
#    'becomes',
#    'key',
#    'In',
#    'paper',
#    'analyze',
#    'mechanism',
#    'design',
#    'problem,',
#    'whose',
#    'allows',
#    'generally',
#    'applicable',
#    'show',
#    'designing',
#    'optimal',
#    'deterministic',
#    'mechanism',
#    'use',
#    'even',
#    'one',
#    'agent',
#    'whose',
#    'type',
#    'objective',
#    'social',
#    'We',
#    'show',
#    'result',
#    'extends',
#    'multiple',
#    'agents',
#    'information.',
#    'We',
#    'show',
#    'mechanism',
#    'allowed',
#    'use',
#    'design',
#    'problem',
#    'linear',
#    'programming',
#    'general',
#    'hence',
#    'This',
#    'fixed',
#    'number',
#    'agents.',
#    'We',
#    'study',
#    'possible',
#    'preferences',
#    'We',
#    'show',
#    'objective',
#    'social',
#    'optimal',
#    'deterministic',
#    'mechanism',
#    'easy',
#    'fact,',
#    'mechanism',
#    'also',
#    'We',
#    'show',
#    'designing',
#    'optimal',
#    'deterministic',
#    'mechanism',
#    'general',
#    'extends',
#    'multiple',
#    'agents.',
#    'Finally,',
#    'show',
#    'optimal',
#    'randomized',
#    'mechanism',
#    'designed',
#    'polynomial',
#    'time',
#    'using',
#    'linear',
#    'programming',
#    'even',
#    'general',
#    'objective',
#    'functions.',
#    'This',
#    'fixed',
#    'number',
#    'agents.']},
#  {'quoted': [],
#   'title': 'A novel solution to mass information storage.',
#   'authors': 'Jun Liu',
#   'date': '2005',
#   'source': 'ICEC',
#   'index': '6055',
#   'abstract': ['With',
#    'growing',
#    'network',
#    'information,',
#    'critical',
#    'demand',
#    'information',
#    'storage',
#    'storage',
#    'systems',
#    'created',
#    'based',
#    'local',
#    'area',
#    'network',
#    'difficult',
#    'satisfy',
#    'requirements',
#    'applications.',
#    'The',
#    'concept',
#    'storage',
#    'network',
#    'implement',
#    'data',
#    'access',
#    'block',
#    'level',
#    'storage',
#    'The',
#    'architecture',
#    'system',
#    'based',
#    'protocol',
#    'presented',
#    'prototype',
#    'developed',
#    'performance',
#    'Experimental',
#    'results',
#    'show',
#    'system',
#    'works',
#    'good',
#    'performance.',
#    'It',
#    'offers',
#    'novel',
#    'solution',
#    'information',
#    'storage',
#    'applications.']},
#  {'quoted': [],
#   'title': 'Expressive commerce and its application to sourcing: how we conducted $35 billion of generalized combinatorial auctions.',
#   'authors': 'Tuomas Sandholm',
#   'date': '2007',
#   'source': 'ICEC',
#   'index': '6238',
#   'abstract': ['several',
#    'services',
#    'We',
#    'introduced',
#    'new',
#    'paradigm',
#    'called',
#    'applied',
#    'It',
#    'combines',
#    'advantages',
#    'highly',
#    'human',
#    'advantages',
#    'electronic',
#    'The',
#    'idea',
#    'demand',
#    'expressed',
#    'greater',
#    'traditional',
#    'electronic',
#    'This',
#    'efficiency',
#    'improvement',
#    'allocation',
#    'market',
#    'problem',
#    'highly',
#    'complex',
#    'combinatorial',
#    'optimization',
#    'problem.',
#    'We',
#    'developed',
#    'tree',
#    'search',
#    'algorithms',
#    'solving',
#    'it.',
#    'We',
#    'using',
#    'created',
#    'The',
#    'also',
#    'able',
#    'express',
#    'production',
#    'problem',
#    'networks',
#    'understanding',
#    'implemented',
#    'instead']},
#  {'quoted': [],
#   'title': "Probe into construction of e-commerce major in undergraduate degree: the experience of Xi'an institute of post and telecoms.",
#   'authors': 'Li Zhang,Qi Li',
#   'date': '2005',
#   'source': 'ICEC',
#   'index': '6249',
#   'abstract': ['The',
#    'point',
#    'paper',
#    'practice',
#    'major',
#    'construction',
#    'focused',
#    'information',
#    'technology',
#    'After',
#    'literature',
#    'applied',
#    'commercial',
#    'gives',
#    'experience',
#    'including',
#    'learning',
#    'capability',
#    'system,',
#    'process,',
#    'specific',
#    'features',
#    'program',
#    'given',
#    'They',
#    'continuous',
#    'scheme',
#    'computer',
#    'science',
#    'Finally,',
#    'future',
#    'changes',
#    'The',
#    'may',
#    'technology',
#    'business',
#    'market',
#    'analysis']},
#  {'quoted': [],
#   'title': 'Polar opposites: next generation languages and architectures.',
#   'authors': 'Kathryn S. McKinley',
#   'date': '2004',
#   'source': 'Memory System Performance',
#   'index': '6308',
#   'abstract': ['hardware',
#    'technology',
#    'modern',
#    'programming',
#    'programming',
#    'languages',
#    'programmers',
#    'high-level',
#    'object-oriented',
#    'languages',
#    'C']},
#  {'quoted': [],
#   'title': 'Segmented winner trees.',
#   'authors': 'Andrew Lim,Sartaj Sahni',
#   'date': '1992',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '6535',
#   'abstract': ['A',
#    'new',
#    'data',
#    'This',
#    'useful',
#    'one',
#    'needs',
#    'represent',
#    'data',
#    'The',
#    'operations',
#    'efficiently',
#    'supported',
#    'unit',
#    'length',
#    'find',
#    'least',
#    'value',
#    'given',
#    'update',
#    'two']},
#  {'quoted': [],
#   'title': 'An FSM model for situation-aware mobile application software systems.',
#   'authors': 'Yu Wang',
#   'date': '2004',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '6719',
#   'abstract': ['desirable',
#    'feature',
#    'application',
#    'software',
#    'systems',
#    'mobile',
#    'computing',
#    'In',
#    'paper,',
#    'present',
#    'extended',
#    'finite',
#    'state',
#    'machine',
#    'model',
#    'mobile',
#    'application',
#    'software',
#    'systems.',
#    'In',
#    'model,',
#    'state',
#    'represents',
#    'condition',
#    'system',
#    'state',
#    'context',
#    'internal',
#    'action',
#    'Each',
#    'state',
#    'transition',
#    'model',
#    'represents',
#    'context',
#    'The',
#    'whole',
#    'finite',
#    'state',
#    'machine',
#    'models',
#    'application',
#    'software',
#    'system',
#    'behavior',
#    'according',
#    'The',
#    'corresponding',
#    'This',
#    'model',
#    'useful',
#    'mobile',
#    'application',
#    'software',
#    'used',
#    'used',
#    'generate',
#    'test',
#    'cases',
#    'represent',
#    'changes',
#    'system',
#    'may',
#    'experience',
#    'mobile',
#    'environment.']},
#  {'quoted': [],
#   'title': 'An improved society of hill-climbers and its application on batch process scheduling.',
#   'authors': 'Lei Zhang',
#   'date': '2005',
#   'source': 'ACM Southeast Regional Conference (1)',
#   'index': '7007',
#   'abstract': ['powerful',
#    'optimization',
#    'algorithm',
#    'large',
#    'range',
#    'problems.',
#    'But',
#    'performance',
#    'algorithm',
#    'sensitive',
#    'must',
#    'determined',
#    'user',
#    'based',
#    'problem.',
#    'In',
#    'performance',
#    'different',
#    'rate',
#    'evaluated',
#    'series',
#    'large',
#    'problems',
#    'robust',
#    'problems',
#    'algorithm',
#    'applied',
#    'important',
#    'type',
#    'optimization',
#    'problem,',
#    'scheduling',
#    'problem',
#    'process.',
#    'The',
#    'results',
#    'show',
#    'powerful',
#    'method',
#    'solving',
#    'process',
#    'scheduling',
#    'problems',
#    'widely',
#    'used']},
#  {'quoted': [],
#   'title': 'Application of particle swarm optimization on batch process scheduling.',
#   'authors': 'Lei Zhang',
#   'date': '2005',
#   'source': 'ACM Southeast Regional Conference (1)',
#   'index': '7028',
#   'abstract': ['The',
#    'scheduling',
#    'process',
#    'problem',
#    'interest',
#    'research',
#    'many',
#    'years.',
#    'methods',
#    'applied',
#    'solve',
#    'problems',
#    'efficient',
#    'algorithm.',
#    'But',
#    'problem',
#    'size',
#    'In',
#    'work,',
#    'optimization',
#    'applied',
#    'solve',
#    'scheduling',
#    'problem',
#    'process.',
#    'The',
#    'results',
#    'show',
#    'powerful',
#    'method',
#    'solving',
#    'process',
#    'scheduling',
#    'problems',
#    'widely',
#    'used']},
#  {'quoted': [],
#   'title': 'Upgrading arc problem with budget constraint.',
#   'authors': 'Li Zhang',
#   'date': '2005',
#   'source': 'ACM Southeast Regional Conference (1)',
#   'index': '7039',
#   'abstract': ['often',
#    'used',
#    'systems.',
#    'In',
#    'real',
#    'world',
#    'pair',
#    'nodes',
#    'using',
#    'using',
#    'instead',
#    'pair',
#    'network',
#    'using',
#    'higher',
#    'speed',
#    'pair',
#    'network.',
#    'These',
#    'times',
#    'network',
#    'critical',
#    'achieving',
#    'This',
#    'paper',
#    'introduces',
#    'problem',
#    'We',
#    'show',
#    'problem',
#    'general',
#    'present',
#    'several']},
#  {'quoted': [],
#   'title': 'Statistical performance critical path analysis for service-oriented systems.',
#   'authors': 'Rui Zhang',
#   'date': '2007',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '7118',
#   'abstract': ['In',
#    'order',
#    'efficient',
#    'performance',
#    'management',
#    'efforts',
#    'must',
#    'focused',
#    'services',
#    'critical',
#    'This',
#    'paper',
#    'flexible',
#    'approach',
#    'identifying',
#    'services',
#    'via',
#    'statistical',
#    'extension',
#    'critical',
#    'path',
#    'algorithm',
#    'The',
#    'solution']},
#  {'quoted': [],
#   'title': 'Reboot-based self-healing strategies for service-oriented systems.',
#   'authors': 'Rui Zhang',
#   'date': '2007',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '7155',
#   'abstract': ['As',
#    'high',
#    'availability',
#    'extends',
#    'increasingly',
#    'popular',
#    'complex',
#    'systems,',
#    'need',
#    'capabilities',
#    'become',
#    'We',
#    'demand',
#    'exploiting',
#    'standard',
#    'software.',
#    'designed',
#    'problems',
#    'service']},
#  {'quoted': [],
#   'title': 'Variations on the binary buddy system for dynamic memory management.',
#   'authors': 'Arie E. Kaufman',
#   'date': '1980',
#   'source': 'ACM Southeast Regional Conference',
#   'index': '7372',
#   'abstract': ['Two',
#    'new',
#    'variations',
#    'binary',
#    'system',
#    'dynamic',
#    'storage',
#    'These',
#    'system',
#    'system,',
#    'smaller',
#    'memory',
#    'blocks',
#    'upon',
#    'attempt',
#    'processor',
#    'execution',
#    'time.',
#    'Simulation',
#    'results',
#    'three',
#    'systems',
#    'two',
#    'new',
#    'variations',
#    'original',
#    'system,',
#    'since',
#    'faster',
#    'difference',
#    'memory',
#    'A',
#    'comparison',
#    'system',
#    'system',
#    'performance.']},
#  {'quoted': [],
#   'title': 'A Universal Construction for Concurrent Objects.',
#   'authors': 'Rachid Guerraoui,Michel Raynal',
#   'date': '2007',
#   'source': 'ARES',
#   'index': '7604',
#   'abstract': ['A',
#    'concurrent',
#    'object',
#    'object',
#    'several',
#    'processes.',
#    'A',
#    'implementation',
#    'object',
#    'operation',
#    'process',
#    'finite',
#    'number',
#    'behavior',
#    'processes',
#    'even',
#    'An',
#    'object',
#    'type',
#    'universal',
#    'objects',
#    'together',
#    'atomic',
#    'allows',
#    'implementing',
#    'concurrent',
#    'object',
#    'defined',
#    'sequential',
#    'A',
#    'universal',
#    'construction',
#    'algorithm,',
#    'based',
#    'atomic',
#    'universal',
#    'that,',
#    'given',
#    'sequential',
#    'object',
#    'type',
#    'provides',
#    'processes',
#    'concurrent',
#    'object',
#    'type',
#    'In',
#    'paper',
#    'shown',
#    'objects',
#    'presented',
#    'universal']},
#  {'quoted': [],
#   'title': 'Concurrency Control using Subject- and Purpose-Oriented (SPO) View.',
#   'authors': 'Tomoya Enokido,Makoto Takizawa',
#   'date': '2007',
#   'source': 'ARES',
#   'index': '7652',
#   'abstract': ['In',
#    'information',
#    'systems,',
#    'multiple',
#    'transactions',
#    'objects',
#    'access',
#    'requests',
#    'multiple',
#    'transactions',
#    'There',
#    'various',
#    'ways',
#    'order',
#    'multiple',
#    'access',
#    'requests',
#    'like',
#    'ordering',
#    'In',
#    'scheduling',
#    'ways',
#    'operating',
#    'systems',
#    'highly',
#    'processes',
#    'performed',
#    'lower',
#    'In',
#    'paper,',
#    'access',
#    'request',
#    'significant',
#    'subject',
#    'performed',
#    'prior',
#    'another',
#    'access',
#    'request',
#    'less',
#    'significant',
#    'We',
#    'define',
#    'terms',
#    'In',
#    'access',
#    'control',
#    'model,',
#    'role',
#    'set',
#    'access',
#    'subject',
#    'role',
#    'issue',
#    'access',
#    'request',
#    'two',
#    'order',
#    'A',
#    'method',
#    'significant',
#    'subject',
#    'performed',
#    'another',
#    'method',
#    'less',
#    'significant',
#    'subject',
#    'A',
#    'transaction',
#    'subject',
#    'associated',
#    'subset',
#    'A',
#    'method',
#    'significant',
#    'purpose',
#    'performed',
#    'another',
#    'method',
#    'less',
#    'significant',
#    'purpose',
#    'In',
#    'paper,',
#    'discuss',
#    'methods',
#    'unique']},
#  {'quoted': [],
#   'title': 'A Hybrid Neural Network Learning System.',
#   'authors': 'Yong Liu',
#   'date': '2004',
#   'source': 'CIT',
#   'index': '8222',
#   'abstract': ['This',
#    'paper',
#    'presents',
#    'hybrid',
#    'learning',
#    'system',
#    'learning',
#    'designing',
#    'neural',
#    'network',
#    'based',
#    'learning',
#    'learning.',
#    'There',
#    'two',
#    'terms',
#    'performance',
#    'function',
#    'one',
#    'learning.',
#    'neural',
#    'network',
#    'could',
#    'learn',
#    'target',
#    'output',
#    'much',
#    'possible',
#    'training',
#    'data.',
#    'By',
#    'neural',
#    'networks',
#    'learn',
#    'simultaneously',
#    'cover',
#    'different',
#    'parts',
#    'training',
#    'data',
#    'order',
#    'learn',
#    'whole',
#    'training',
#    'data.',
#    'The',
#    'learning',
#    'hybrid',
#    'learning',
#    'system',
#    'studied',
#    'based',
#    'among',
#    'individual',
#    'networks']},
#  {'quoted': [],
#   'title': 'Protein Structure Prediction and Interpretation with Support Vector Machines and Decision Trees.',
#   'authors': 'Yi Pan',
#   'date': '2005',
#   'source': 'CIT',
#   'index': '8325',
#   'abstract': ['structures',
#    'sequences',
#    'using',
#    'computers',
#    'important',
#    'step',
#    '3D',
#    'structures',
#    'functions',
#    'hence',
#    'theoretical',
#    'practical',
#    'areas',
#    'engineering',
#    'design.',
#    'In',
#    'talk,',
#    'discuss',
#    'new',
#    'results',
#    'structure',
#    'prediction',
#    'using',
#    'We',
#    'also',
#    'discuss',
#    'use',
#    'combination',
#    'understand',
#    'prediction',
#    'rule',
#    'good',
#    'useful',
#    'experiments',
#    'may',
#    'lead',
#    'prediction',
#    'A',
#    'novel',
#    'approach',
#    'rule',
#    'clustering',
#    'generation',
#    'also',
#    'briefly',
#    'discussed.']},
#  {'quoted': [],
#   'title': 'Evolutionary Programming with Operator Adaptation.',
#   'authors': 'Yong Liu',
#   'date': '2007',
#   'source': 'CIT',
#   'index': '8727',
#   'abstract': ['This',
#    'paper',
#    'investigated',
#    'programming',
#    'adaptation',
#    'level',
#    'The',
#    'update',
#    'level',
#    'feedback',
#    'applied',
#    'change',
#    'individual',
#    'Experimental',
#    'shown',
#    'long',
#    'could',
#    'smaller',
#    'average',
#    'step',
#    'evolution',
#    'step',
#    'distribution',
#    'values',
#    'could',
#    'become',
#    'long',
#    'applied',
#    'rather',
#    'low']},
#  {'quoted': [],
#   'title': 'Concept Formation and Learning: A Cognitive Informatics Perspectiv.',
#   'authors': 'Yiyu Yao',
#   'date': '2004',
#   'source': 'IEEE ICCI',
#   'index': '9019',
#   'abstract': ['basic',
#    'human',
#    'intelligence',
#    'perspective',
#    'framework',
#    'concept',
#    'learning.',
#    'It',
#    'combines',
#    'science',
#    'machine',
#    'learning',
#    'approaches.',
#    'The',
#    'issues',
#    'various',
#    'views',
#    'concepts',
#    'learning',
#    'methods',
#    'presented',
#    'based',
#    'classical',
#    'view']},
#  {'quoted': [],
#   'title': 'Exploring Sub-Block Value Reuse for Superscalar Processors.',
#   'authors': 'Jian Huang,David J. Lilja',
#   'date': '2000',
#   'source': 'IEEE PACT',
#   'index': '9701',
#   'abstract': ['The',
#    'performance',
#    'potential',
#    'value',
#    'reuse',
#    'mechanism',
#    'depends',
#    'reuse',
#    'detection',
#    'time,',
#    'number',
#    'amount',
#    'work',
#    'reuse',
#    'Since',
#    'larger',
#    'instruction',
#    'groups',
#    'typically',
#    'reuse',
#    'opportunities',
#    'smaller',
#    'also',
#    'provide',
#    'greater',
#    'benefit',
#    'process,',
#    'important',
#    'find',
#    'point',
#    'provides',
#    'overall',
#    'performance',
#    'We',
#    'propose',
#    'new',
#    'mechanism',
#    'called',
#    'reuse',
#    'reuse',
#    'number',
#    'reuse',
#    'Our',
#    'simulation',
#    'results',
#    'show',
#    'reuse',
#    'compiler',
#    'consistent',
#    'potential',
#    'improve',
#    'performance']},
#  {'quoted': [],
#   'title': 'Instruction Scheduling for Clustered VLIW DSPs.',
#   'authors': 'Rainer Leupers',
#   'date': '2000',
#   'source': 'IEEE PACT',
#   'index': '9754',
#   'abstract': ['Recent',
#    'digital',
#    'signal',
#    'processors',
#    'show',
#    'data',
#    'path',
#    'allows',
#    'C',
#    'generate',
#    'efficient',
#    'However,',
#    'still',
#    'special',
#    'code',
#    'generation',
#    'In',
#    'order',
#    'reduce',
#    'number',
#    'register',
#    'file',
#    'needed',
#    'provide',
#    'data',
#    'multiple',
#    'functional',
#    'working',
#    'data',
#    'path',
#    'may',
#    'several',
#    'limited',
#    'capabilities',
#    'values',
#    'different',
#    'An',
#    'example',
#    'well-known',
#    'For',
#    'tasks',
#    'scheduling',
#    'partitioning',
#    'clusters',
#    'highly',
#    'This',
#    'paper',
#    'presents',
#    'new',
#    'instruction',
#    'scheduling',
#    'approach,',
#    'contrast',
#    'earlier',
#    'work,',
#    'partitioning',
#    'scheduling',
#    'single',
#    'achieve',
#    'high',
#    'code',
#    'We',
#    'show',
#    'proposed',
#    'technique',
#    'generating',
#    'efficient',
#    'code',
#    'commercial',
#    'code']},
#  {'quoted': [],
#   'title': 'XML Data Services.',
#   'authors': 'Michael J. Carey',
#   'date': '2005',
#   'source': 'IEEE SCC',
#   'index': '10033',
#   'abstract': ['We',
#    'address',
#    'new',
#    'world',
#    'Web',
#    'services',
#    'architectures',
#    'data',
#    'We',
#    'data',
#    'modeling',
#    'concepts',
#    'world',
#    'services,',
#    'approach',
#    'data',
#    'access',
#    'collection',
#    'data',
#    'services.',
#    'We',
#    'show',
#    'approach',
#    'XML',
#    'XML',
#    'Web',
#    'services,',
#    'We',
#    'show',
#    'approach',
#    'provides',
#    'uniform',
#    'framework',
#    'data',
#    'underlying',
#    'including',
#    'data',
#    'sources',
#    'well',
#    'data',
#    'Web',
#    'services.',
#    'We',
#    'also',
#    'show',
#    'approach',
#    'yields',
#    'data',
#    'services',
#    'easily',
#    'efficiently']},
#  {'quoted': [],
#   'title': 'Trust2: Developing Trust in Peer-to-Peer Environments.',
#   'authors': 'Yan Wang,Vijay Varadharajan',
#   'date': '2005',
#   'source': 'IEEE SCC',
#   'index': '10174',
#   'abstract': ['In',
#    'needs',
#    'services',
#    'This',
#    'requires',
#    'trust',
#    'evaluation',
#    'prior',
#    'This',
#    'paper',
#    'presents',
#    'novel',
#    'dynamic',
#    'trust',
#    'evaluation',
#    'model,',
#    'measure',
#    'thus',
#    'noise',
#    'obtain',
#    'accurate',
#    'objective',
#    'trust',
#    'In',
#    'model,',
#    'prior',
#    'trust',
#    'value',
#    'results',
#    'given',
#    'trust',
#    'values',
#    'results',
#    'In',
#    'aggregation',
#    'trust',
#    'weight',
#    'becomes',
#    'higher',
#    'process,',
#    'This',
#    'leads',
#    'filtering',
#    'low',
#    'improvement',
#    'trust']},
#  {'quoted': [],
#   'title': 'Optimal Broadcasting in Injured Hypercubes Using Directed Safety Levels.',
#   'authors': 'Jie Wu',
#   'date': '2001',
#   'source': 'ISCA PDCS',
#   'index': '10764',
#   'abstract': ['communication',
#    'faulty',
#    'using',
#    'directed',
#    'safety',
#    'levels',
#    'studied',
#    'paper.',
#    'In',
#    'approach,',
#    'node',
#    'hypercube',
#    'associated',
#    'sequence',
#    'directed',
#    'safety',
#    'A',
#    'directed',
#    'safety',
#    'level',
#    'associated',
#    'node',
#    'measure',
#    'broadcast',
#    'capability',
#    'performing',
#    'optimal',
#    '-',
#    'By',
#    'optimal',
#    'broadcast',
#    'message',
#    'shortest',
#    'path',
#    '(i.e.,',
#    'length',
#    'path',
#    'distance',
#    'source',
#    'safety',
#    'levels',
#    'based',
#    'special',
#    'scheme',
#    'generalized',
#    'safety',
#    'level',
#    'model',
#    'n',
#    '-',
#    '1',
#    'information',
#    'among',
#    'nodes.',
#    'In',
#    'model,',
#    'fault',
#    'information',
#    'nodes',
#    'within',
#    'represented',
#    'better',
#    'capture',
#    'link',
#    'fault',
#    'information',
#    'nodes',
#    'regular',
#    'safety',
#    'level',
#    'model.',
#    'node',
#    'guaranteed',
#    'node',
#    'defined',
#    'terms',
#    'directed',
#    'safety',
#    'levels',
#    'associated',
#    'The',
#    'directed',
#    'safety',
#    'level',
#    'model',
#    '=',
#    '1',
#    '=',
#    '2',
#    'complexity',
#    'regular',
#    'safety',
#    'level',
#    'model.',
#    'Simulation',
#    'results',
#    'show',
#    'significant',
#    'improvement',
#    'terms',
#    'optimal',
#    'broadcast',
#    'capability']},
#  {'quoted': [],
#   'title': 'A Compiler Framework for Supporting Speculative Multicore Processors.',
#   'authors': 'Pen-Chung Yew',
#   'date': '2007',
#   'source': 'Asia-Pacific Computer Systems Architecture Conference',
#   'index': '11438',
#   'abstract': ['As',
#    'technology',
#    'currently',
#    'computer',
#    'industry',
#    'power',
#    'consumption',
#    'improve',
#    'performance',
#    'improvement',
#    'single',
#    'application',
#    'systems',
#    'remains',
#    'important',
#    'challenging',
#    'on-chip',
#    'communication',
#    'latency',
#    'using',
#    'parallelism',
#    'improve',
#    'number',
#    'per',
#    'clock',
#    'i.e.,',
#    'improve',
#    'performance,',
#    'shown',
#    'effective',
#    'many',
#    'applications.',
#    'However,',
#    'program',
#    'characteristics',
#    'applications,',
#    'effective',
#    'schemes']},
#  {'quoted': [],
#   'title': 'Self-Emergence of Structures in Gene Expression Programming.',
#   'authors': 'Xin Li',
#   'date': '2005',
#   'source': 'AAAI',
#   'index': '11954',
#   'abstract': ['This',
#    'work',
#    'improving',
#    'problem',
#    'solving',
#    'ability',
#    'algorithm',
#    'complex',
#    'data',
#    'mining',
#    'tasks',
#    'structures',
#    'process.',
#    'The',
#    'main',
#    'include',
#    'constant',
#    'techniques',
#    'good',
#    'functional',
#    'structures',
#    'analysis',
#    'current',
#    'implementation',
#    'scheme',
#    'novel',
#    'structures',
#    'achieve',
#    'flexible',
#    'search',
#    'process',
#    'solutions',
#    'higher']},
#  {'quoted': ['12360', '1060979'],
#   'title': 'Computing Slater Rankings Using Similarities among Candidates.',
#   'authors': 'Vincent Conitzer',
#   'date': '2006',
#   'source': 'AAAI',
#   'index': '12356',
#   'abstract': ['(or',
#    'general',
#    'method',
#    'preferences',
#    'multiple',
#    'agents.',
#    'One',
#    'important',
#    'rule',
#    'It',
#    'ranking',
#    '(or',
#    'minimize',
#    'number',
#    'pairs',
#    'ranking',
#    'two',
#    'The',
#    'use',
#    'rule',
#    'lack',
#    'techniques',
#    'compute',
#    'In',
#    'paper,',
#    'show',
#    'problem',
#    'smaller',
#    'set',
#    'similar',
#    'We',
#    'show',
#    'technique',
#    'compute',
#    'ranking',
#    'linear',
#    'time',
#    'graph',
#    'For',
#    'general',
#    'case,',
#    'also',
#    'give',
#    'efficient',
#    'algorithm',
#    'finding',
#    'set',
#    'similar',
#    'We',
#    'provide',
#    'experimental',
#    'results',
#    'show',
#    'technique',
#    'significantly',
#    'search',
#    'algorithms,',
#    'Finally,',
#    'also',
#    'use',
#    'technique',
#    'similar',
#    'sets',
#    'show',
#    'computing',
#    'optimal',
#    'ranking',
#    'even']},
#  {'quoted': [],
#   'title': 'Complexity of Manipulating Elections with Few Candidates.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2002',
#   'source': 'AAAI/IAAI',
#   'index': '12359',
#   'abstract': ['In',
#    'multiagent',
#    'agents',
#    'different',
#    'aggregation',
#    'central',
#    'general',
#    'method',
#    'results',
#    'shown',
#    'general',
#    'protocols',
#    'One',
#    'could',
#    'avoid',
#    'manipulation',
#    'using',
#    'protocols',
#    'determining',
#    'manipulation',
#    'among',
#    'computational',
#    'reasonable',
#    'measure',
#    'computational',
#    'Some',
#    'earlier',
#    'work',
#    'done',
#    'number',
#    'We',
#    'derive',
#    'results',
#    'common',
#    'setting',
#    'number',
#    'small',
#    'number',
#    'We',
#    'show',
#    'complete',
#    'information',
#    'individual',
#    'manipulation',
#    'manipulation',
#    'easy',
#    'However,',
#    'manipulation',
#    'weighted',
#    'protocols',
#    'manipulation',
#    'protocols',
#    'used',
#    'make',
#    'manipulation',
#    'Finally,',
#    'show',
#    'weak',
#    'weighted',
#    'manipulation',
#    'complete',
#    'information',
#    'hard',
#    'individual',
#    'manipulation',
#    'hard',
#    'uncertainty']},
#  {'quoted': ['12359'],
#   'title': 'Vote Elicitation: Complexity and Strategy-Proofness.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2002',
#   'source': 'AAAI/IAAI',
#   'index': '12360',
#   'abstract': ['central',
#    'problem',
#    'received',
#    'significant',
#    'attention',
#    'It',
#    'also',
#    'key',
#    'problem',
#    'multiagent',
#    'systems,',
#    'received',
#    'little',
#    'attention',
#    'In',
#    'agents',
#    'may',
#    'different',
#    'preferences',
#    'often',
#    'must',
#    'using',
#    'This',
#    'leads',
#    'interesting',
#    'issues',
#    'information',
#    'agent',
#    'depends',
#    'agents',
#    'preferences',
#    'In',
#    'paper',
#    'study',
#    'effective',
#    'common',
#    'It',
#    'even',
#    'easy',
#    'protocols',
#    'determining',
#    'effectively',
#    'even',
#    'agents',
#    'The',
#    'protocol',
#    'effective',
#    'We',
#    'also',
#    'show',
#    'introduces',
#    'additional',
#    'opportunities',
#    'manipulation',
#    'We',
#    'demonstrate',
#    'space',
#    'schemes',
#    'additional',
#    'issues']},
#  {'quoted': ['12359'],
#   'title': 'Computing Shapley Values, Manipulating Value Division Schemes, and Checking Core Membership in Multi-Issue Domains.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2004',
#   'source': 'AAAI',
#   'index': '12361',
#   'abstract': ['key',
#    'problem',
#    'automated',
#    'among',
#    'agents.',
#    'In',
#    'order',
#    'key',
#    'question',
#    'must',
#    'solution',
#    'concepts',
#    'computational',
#    'questions',
#    'around',
#    'solution',
#    'concepts',
#    'received',
#    'little',
#    'We',
#    'study',
#    'representation',
#    'functions',
#    'allows',
#    'agents',
#    'number',
#    'independent',
#    'issues',
#    'agents',
#    'For',
#    'example,',
#    'may',
#    'set',
#    'tasks',
#    'agents',
#    'could',
#    'task',
#    'generates',
#    'certain',
#    'amount',
#    'value',
#    'well',
#    'task',
#    'Given',
#    'show',
#    'quickly',
#    'compute',
#    'value',
#    'scheme',
#    'certain',
#    'We',
#    'show',
#    'based',
#    'value',
#    'known',
#    'manipulation',
#    'order',
#    'agents',
#    'manipulation',
#    'Thus,',
#    'computational',
#    'complexity',
#    'Finally,',
#    'show',
#    'given',
#    'value',
#    'determining',
#    'whether',
#    'case',
#    'computational',
#    'complexity',
#    'increase']},
#  {'quoted': ['745797', '592644'],
#   'title': 'Expressive Negotiation in Settings with Externalities.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2005',
#   'source': 'AAAI',
#   'index': '12362',
#   'abstract': ['In',
#    'recent',
#    'years,',
#    'certain',
#    'combinatorial',
#    'combinatorial',
#    'become',
#    'important',
#    'research',
#    'topic',
#    'AI',
#    'community.',
#    'A',
#    'assumption',
#    'agents',
#    'variable',
#    'whether',
#    'takes',
#    'place',
#    'variable',
#    'set.',
#    'To',
#    'widely',
#    'studied',
#    'combinatorial',
#    'In',
#    'paper,',
#    'introduce',
#    'We',
#    'show',
#    'number',
#    'key',
#    'special',
#    'cases,',
#    'find',
#    'solution',
#    '(and',
#    'therefore',
#    'maximum',
#    'social',
#    'However,',
#    'one',
#    'important',
#    'special',
#    'case,',
#    'give',
#    'algorithm',
#    'solution',
#    'agent',
#    'linear',
#    'number',
#    'utility',
#    'functions',
#    'constant',
#    'social',
#    'however,',
#    'remains',
#    'even',
#    'We',
#    'also',
#    'demonstrate',
#    'special',
#    'case',
#    'solved',
#    'polynomial',
#    'time',
#    'linear']},
#  {'quoted': ['268834', '592763'],
#   'title': 'A Generalized Strategy Eliminability Criterion and Computational Methods for Applying It.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2005',
#   'source': 'AAAI',
#   'index': '12363',
#   'abstract': ['We',
#    'define',
#    'generalized',
#    'strategy',
#    'games',
#    'considers',
#    'whether',
#    'given',
#    'strategy',
#    'relative',
#    'given',
#    '&',
#    'subsets',
#    'We',
#    'show',
#    'definition',
#    'criteria',
#    'sets',
#    'small',
#    'Nash',
#    'equilibrium',
#    'sets',
#    'large',
#    'We',
#    'show',
#    'checking',
#    'whether',
#    'strategy',
#    'according',
#    'sets',
#    'large',
#    'possible',
#    'sets',
#    'size',
#    'We',
#    'give',
#    'alternative',
#    'definition',
#    'show',
#    'equivalent',
#    'using',
#    'We',
#    'show',
#    'alternative',
#    'definition',
#    'integer',
#    'program',
#    'polynomial',
#    'size',
#    'number',
#    'integer',
#    'variables',
#    'checking',
#    'whether',
#    'strategy',
#    'according',
#    'done',
#    'polynomial',
#    'time,',
#    'given',
#    'sets',
#    'Finally,',
#    'study',
#    'using']},
#  {'quoted': ['12359'],
#   'title': 'Nonexistence of Voting Rules That Are Usually Hard to Manipulate.',
#   'authors': 'Vincent Conitzer,Tuomas Sandholm',
#   'date': '2006',
#   'source': 'AAAI',
#   'index': '12364',
#   'abstract': ['preferences',
#    'agents',
#    'key',
#    'problem',
#    'multiagent',
#    'systems,',
#    'one',
#    'general',
#    'method',
#    'theorem',
#    'shows',
#    'three',
#    'reasonable',
#    'rules',
#    'sense',
#    'exist',
#    'would',
#    'benefit',
#    'preferences',
#    'To',
#    'result,',
#    'recent',
# ...
#   'index': '268781',
#   'abstract': ['This',
#    'paper',
#    'proposes',
#    'distributed',
#    'solution',
#    'basis',
#    'problem.',
#    'The',
#    'solution',
#    'based',
#    'technique',
#    'called',
#    'us',
#    'reduce',
#    'amount',
#    'work',
#    'necessary',
#    'special',
#    'properties',
#    'As',
#    'shown',
#    'algorithm',
#    'used',
#    'minimum',
#    'weight',
#    'spanning',
#    'tree',
#    'computed',
#    'network,',
#    'k',
#    'edges',
#    'time',
#    'The',
#    'ACM',
#    'Portal',
#    'published',
#    'Association',
#    'Computing',
#    'Machinery.',
#    'Copyright',
#    '©',
#    '2010',
#    'ACM,',
#    'Inc.',
#    'Terms',
#    'Usage',
#    'Privacy',
#    'Policy',
#    'Code',
#    'Ethics',
#    'Contact',
#    'Us',
#    'Useful',
#    'downloads:',
#    'Adobe',
#    'Acrobat',
#    'QuickTime',
#    'Windows',
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': ['972738', '211677'],
#   'title': 'Algorithms, Games, and the Internet.',
#   'authors': 'Christos H. Papadimitriou',
#   'date': '2001',
#   'source': 'ICALP',
#   'index': '268834',
#   'abstract': ['If',
#    'Internet',
#    'next',
#    'great',
#    'subject',
#    'Computer',
#    'model',
#    'likely',
#    'prove',
#    'useful',
#    'In',
#    'talk',
#    'I',
#    'survey',
#    'opportunities',
#    'challenges',
#    'important']},
#  {'quoted': [],
#   'title': 'The VLSI Revolution in Theoretical Circles.',
#   'authors': 'Arnold L. Rosenberg',
#   'date': '1984',
#   'source': 'ICALP',
#   'index': '268934',
#   'abstract': ['pages',
#    'personal',
#    'effect',
#    'circuit',
#    'technology',
#    'Computer',
#    'field',
#    'together',
#    'much',
#    'effect',
#    'earlier',
#    'The',
#    'includes',
#    'well',
#    'theoretical']},
#  {'quoted': [],
#   'title': 'Quick k-Median, k-Center, and Facility Location for Sparse Graphs.',
#   'authors': 'Mikkel Thorup',
#   'date': '2001',
#   'source': 'ICALP',
#   'index': '269122',
#   'abstract': ['We',
#    'present',
#    'time',
#    'space',
#    'constant',
#    'factor',
#    'approximation',
#    'algorithms',
#    'location',
#    'problems',
#    'assignment',
#    'costs',
#    'shortest',
#    'path',
#    'weighted',
#    'graph',
#    'n',
#    'vertices',
#    'For',
#    'location',
#    'problems,',
#    'time',
#    'space',
#    'algorithms',
#    'already',
#    'addressing',
#    'large',
#    'sparse',
#    'graphs.',
#    'An',
#    'application',
#    'could',
#    'content',
#    'The',
#    'Internet',
#    'large',
#    'changes',
#    'time',
#    'solution',
#    'would',
#    'likely',
#    'long']},
#  {'quoted': [],
#   'title': 'Credentials-Based Authorization: Evaluation and Implementation.',
#   'authors': 'Fred B. Schneider',
#   'date': '2007',
#   'source': 'ICALP',
#   'index': '269198',
#   'abstract': ['new',
#    'operating',
#    'system',
#    'runs',
#    'computers',
#    'secure',
#    'designed',
#    'support',
#    'construction',
#    'actions',
#    'measure',
#    'trust',
#    'assumptions']},
#  {'quoted': [],
#   'title': 'Ushering in a New Era of Algorithm Design.',
#   'authors': 'Bernard Chazelle',
#   'date': '2007',
#   'source': 'ICALP',
#   'index': '269250',
#   'abstract': ['data',
#    'together',
#    'basic',
#    'algorithm',
#    'design',
#    'Computing',
#    'data',
#    'data',
#    'property',
#    'algorithms',
#    'parts',
#    'growing',
#    'using',
#    'algorithms',
#    'modeling',
#    'tools',
#    'natural',
#    'I',
#    'discuss',
#    'particular,',
#    'algorithms,',
#    'online',
#    'algorithms.']},
#  {'quoted': [],
#   'title': 'On the Approximability of Average Completion Time Scheduling under Precedence Constraints.',
#   'authors': 'Gerhard J. Woeginger',
#   'date': '2001',
#   'source': 'ICALP',
#   'index': '269259',
#   'abstract': ['We',
#    'consider',
#    'scheduling',
#    'problem',
#    'minimizing',
#    'average',
#    'weighted',
#    'job',
#    'time',
#    'single',
#    'machine',
#    'constraints.',
#    'We',
#    'show',
#    'problem',
#    'arbitrary',
#    'job',
#    'special',
#    'case',
#    'problem',
#    'job',
#    'weights',
#    'several',
#    'special',
#    'cases',
#    'problem',
#    'threshold',
#    'respect',
#    'polynomial',
#    'time',
#    'approximation',
#    'algorithms.',
#    'Moreover,',
#    'special',
#    'case',
#    'order',
#    'constraints',
#    'special',
#    'case',
#    'convex',
#    'give',
#    'polynomial',
#    'time',
#    'approximation',
#    'algorithm',
#    'worst',
#    'case',
#    'performance',
#    'guarantee',
#    'close',
#    'ratio',
#    '+']},
#  {'quoted': [],
#   'title': 'Internet Ad Auctions: Insights and Directions.',
#   'authors': 'S. Muthukrishnan',
#   'date': '2008',
#   'source': 'ICALP (1)',
#   'index': '269362',
#   'abstract': ['On',
#    'different',
#    'video',
#    'objects',
#    'underlying',
#    'content',
#    'There',
#    'industry',
#    'behind',
#    'management',
#    'face',
#    'number',
#    'algorithmic',
#    'This',
#    'present',
#    'small',
#    'selection',
#    'problems,',
#    'open',
#    'research',
#    'The',
#    'ACM',
#    'Portal',
#    'published',
#    'Association',
#    'Computing',
#    'Machinery.',
#    'Copyright',
#    '©',
#    '2010',
#    'ACM,',
#    'Inc.',
#    'Terms',
#    'Usage',
#    'Privacy',
#    'Policy',
#    'Code',
#    'Ethics',
#    'Contact',
#    'Us',
#    'Useful',
#    'downloads:',
#    'Adobe',
#    'Acrobat',
#    'QuickTime',
#    'Windows',
#    'Media',
#    'Player',
#    'Real',
#    'Player']},
#  {'quoted': [],
#   'title': 'A Model of Facial Expression for 3D Avatar.',
#   'authors': 'Zhen Liu',
#   'date': '2007',
#   'source': 'International Conference on Computational Science (3)',
#   'index': '280794',
#   'abstract': ['3D',
#    'useful',
#    '3D',
#    'complex',
#    'construct',
#    'complex',
#    'expression',
#    'interesting',
#    'The',
#    'concept',
#    'vector',
#    'presented.',
#    'state',
#    '3D',
#    'vector',
#    'basic',
#    'The',
#    'concept',
#    'expression',
#    'vector',
#    'expression',
#    'expression',
#    'vector',
#    'basic',
#    'expression',
#    'mapping',
#    'set',
#    'vector',
#    'space',
#    'expression',
#    'vector',
#    'space.',
#    'A',
#    'carried']},
#  {'quoted': [],
#   'title': "Compatible Observability Don't Cares Revisited.",
#   'authors': 'Robert K. Brayton',
#   'date': '2001',
#   'source': 'ICCAD',
#   'index': '281764',
#   'abstract': ['We',
#    'first',
#    'examine',
#    'definition',
#    'set',
#    'We',
#    'discuss',
#    'computation',
#    'output',
#    'show',
#    'example,',
#    'results',
#    'current',
#    'implementation',
#    'computation',
#    'result',
#    'independent',
#    'implementation',
#    'The',
#    'computation',
#    'proved',
#    'primary',
#    'inputs',
#    'local',
#    'combine',
#    'part',
#    'network.',
#    'form',
#    'local',
#    'parts',
#    'network.',
#    'Both',
#    'shown',
#    'We',
#    'give',
#    'method',
#    'kinds',
#    'local',
#    'nodes',
#    'network']},
#  {'quoted': [],
#   'title': 'Test scheduling for core-based systems.',
#   'authors': 'Krishnendu Chakrabarty',
#   'date': '1999',
#   'source': 'ICCAD',
#   'index': '281814',
#   'abstract': ['We',
#    'present',
#    'optimal',
#    'solutions',
#    'test',
#    'scheduling',
#    'problem',
#    'systems.',
#    'We',
#    'show',
#    'test',
#    'scheduling',
#    'equivalent',
#    'scheduling',
#    'problem',
#    'therefore',
#    'However,',
#    'problem',
#    '=',
#    'solved',
#    'polynomial',
#    'time.',
#    'For',
#    'general',
#    'case',
#    '>',
#    'present',
#    'linear',
#    'programming',
#    'model',
#    'optimal',
#    'scheduling',
#    'apply',
#    'representative',
#    'system',
#    'using',
#    'We',
#    'also',
#    'extend',
#    'model',
#    'allow',
#    'optimal',
#    'test',
#    'set',
#    'selection',
#    'set',
#    'Finally,',
#    'present',
#    'efficient',
#    'heuristic',
#    'algorithm',
#    'larger',
#    'systems',
#    'model',
#    'may']},
#  {'quoted': [],
#   'title': 'RAFT191486: a novel program for rapid-fire test and diagnosis of digital logic for marginal delays and delay faults.',
#   'authors': 'Abhijit Chatterjee,Jacob A. Abraham',
#   'date': '1994',
#   'source': 'ICCAD',
#   'index': '281892',
#   'abstract': ['The',
#    'problem',
#    'delay',
#    'detection',
#    'performance',
#    'become',
#    'even',
#    'critical',
#    'due',
#    'clock',
#    'In',
#    'paper,',
#    'methodology',
#    'detection',
#    'digital',
#    'circuits',
#    'diagnosis',
#    'delay',
#    'failures',
#    'A',
#    'new',
#    'test',
#    'application',
#    'methodology',
#    'proposed',
#    'test',
#    'vectors',
#    'may',
#    'applied',
#    'digital',
#    'combinational',
#    'circuits',
#    'smaller',
#    'critical',
#    'path',
#    'delay',
#    'circuit',
#    'signal',
#    'analysis',
#    'used',
#    'test',
#    'results.',
#    'The',
#    'resulting',
#    'tests',
#    'called',
#    '(for',
#    'allow',
#    'classification',
#    'circuits',
#    'along',
#    'continuous']},
#  {'quoted': [],
#   'title': 'Test generation for delay faults in non-scan and partial scan sequential circuits.',
#   'authors': 'Kwang-Ting Cheng',
#   'date': '1992',
#   'source': 'ICCAD',
#   'index': '281900',
#   'abstract': ['A',
#    'recently',
#    'proposed',
#    'transition',
#    'fault',
#    'model',
#    'sequential',
#    'circuits',
#    'considered.',
#    'In',
#    'fault',
#    'model,',
#    'transition',
#    'fault',
#    'fault',
#    'fault',
#    'type',
#    'fault',
#    'It',
#    'observed',
#    'comprehensive',
#    'functional',
#    'verification',
#    'sequence',
#    'sequence',
#    'high',
#    'stuck-at',
#    'fault',
#    'coverage',
#    'gives',
#    'high',
#    'transition',
#    'fault',
#    'coverage',
#    'sequential',
#    'circuits.',
#    'test',
#    'generation',
#    'delay',
#    'faults',
#    'required',
#    'coverage',
#    'reasonable',
#    'test',
#    'generation',
#    'algorithm',
#    'fault',
#    'model',
#    'presented.',
#    'With',
#    'use',
#    'fault',
#    'tests',
#    'transition',
#    'faults',
#    'generated',
#    'using',
#    'stuck-at',
#    'fault',
#    'test',
#    'generation',
#    'algorithm',
#    'The',
#    'test',
#    'integrated',
#    'sequential',
#    'circuit',
#    'delay',
#    'fault',
#    'Experimental',
#    'results',
#    'benchmark',
#    'circuits',
#    'designs',
#    'presented.',
#    'For',
#    'partial',
#    'scan',
#    'test',
#    'application',
#    'scheme',
#    'detecting',
#    'transition',
#    'faults',
#    'described.',
#    'test',
#    'generation',
#    'fault',
#    'simulation',
#    'algorithms',
#    'required',
#    'partial',
#    'scan',
#    'circuits',
#    'presented.',
#    'Experimental',
#    'results',
#    'presented']},
#  {'quoted': ['281974'],
#   'title': 'Optimal wiresizing for interconnects with multiple sources.',
#   'authors': 'Jason Cong,Lei He',
#   'date': '1995',
#   'source': 'ICCAD',
#   'index': '281970',
#   'abstract': ['The',
#    'optimal',
#    'problem',
#    'multiple',
#    'sources',
#    'studied',
#    'distributed',
#    'delay',
#    'model.',
#    'We',
#    'source',
#    'set',
#    'show',
#    'optimal',
#    'solution',
#    'satisfies',
#    'number',
#    'interesting',
#    'local',
#    'property',
#    'general',
#    'Furthermore,',
#    'study',
#    'optimal',
#    'problem',
#    'using',
#    'variable',
#    'grid',
#    'These',
#    'properties',
#    'lead',
#    'efficient',
#    'algorithms',
#    'compute',
#    'lower',
#    'upper',
#    'bounds',
#    'optimal',
#    'results',
#    'processor',
#    'show',
#    'delay',
#    'reduction',
#    'compared',
#    'In',
#    'addition,',
#    'algorithm',
#    'based',
#    'variable',
#    'grid',
#    'yields',
#    'two',
#    'without',
#    'loss',
#    'compared',
#    'fixed',
#    'grid',
#    'based',
#    'methods.']},
#  {'quoted': ['281974'],
#   'title': 'An efficient approach to simultaneous transistor and interconnect sizing.',
#   'authors': 'Jason Cong,Lei He',
#   'date': '1996',
#   'source': 'ICCAD',
#   'index': '281971',
#   'abstract': ['In',
#    'paper,',
#    'study',
#    'problem.',
#    'We',
#    'define',
#    'class',
#    'optimization',
#    'problems',
#    'programs',
#    'general',
#    'property',
#    'programs.',
#    'We',
#    'show',
#    'problems',
#    'number',
#    'delay',
#    'models',
#    'programs',
#    'propose',
#    'efficient',
#    'algorithm',
#    'based',
#    'When',
#    'used',
#    'solve',
#    'problem',
#    'real',
#    'reduces',
#    'maximum',
#    'delay',
#    'reduces',
#    'power',
#    'consumption',
#    'factor',
#    'compared',
#    'original',
#    'When',
#    'used',
#    'solve',
#    'problem,',
#    'achieves',
#    'Moreover,',
#    'algorithm',
#    'clock']},
#  {'quoted': [],
#   'title': 'Simultaneous driver and wire sizing for performance and power optimization.',
#   'authors': 'Jason Cong,Cheng-Kok Koh',
#   'date': '1994',
#   'source': 'ICCAD',
#   'index': '281974',
#   'abstract': ['In',
#    'paper,',
#    'study',
#    'problem',
#    'two',
#    'objective',
#    'delay',
#    'combined',
#    'delay',
#    'power',
#    'We',
#    'present',
#    'general',
#    'problem',
#    'two',
#    'based',
#    'distributed',
#    'delay',
#    'model',
#    'power',
#    'power',
#    'We',
#    'show',
#    'several',
#    'interesting',
#    'properties',
#    'optimal',
#    'solutions',
#    'two',
#    'including',
#    'important',
#    'result',
#    'relationship',
#    'optimal',
#    'These',
#    'results',
#    'lead',
#    'polynomial',
#    'time',
#    'algorithms',
#    'computing',
#    'lower',
#    'upper',
#    'bounds',
#    'optimal',
#    'solutions',
#    'two',
#    'efficient',
#    'algorithms',
#    'computing',
#    'optimal',
#    'solutions',
#    'two',
#    'We',
#    'implemented',
#    'algorithms',
#    'compared',
#    'existing',
#    'design',
#    'methods',
#    'independent',
#    'simulations',
#    'shows',
#    'methods',
#    'reduce',
#    'delay',
#    'power',
#    'compared',
#    'existing',
#    'design',
#    'methods.']},
#  {'quoted': [],
#   'title': 'Interconnect layout optimization under higher-order RLC model.',
#   'authors': 'Jason Cong,Cheng-Kok Koh',
#   'date': '1997',
#   'source': 'ICCAD',
#   'index': '281975',
#   'abstract': ['optimization',
#    'problem',
#    'model',
#    'delay',
#    'also',
#    'circuits',
#    'signal',
#    'We',
#    'propose',
#    'approach',
#    'considers',
#    'optimization',
#    'optimization',
#    'Our',
#    'algorithm',
#    'considers',
#    'large',
#    'class',
#    'routing',
#    'trees',
#    'trees',
#    'We',
#    'construct',
#    'set',
#    'providing',
#    'among',
#    'signal',
#    'routing',
#    'Using',
#    'new',
#    'computation',
#    'algorithm,',
#    'construction',
#    'computation',
#    'facilitate',
#    'accurate',
#    'delay',
#    'evaluation',
#    'Experimental',
#    'results',
#    'show',
#    'algorithm',
#    'able',
#    'construct',
#    'set',
#    'providing',
#    'among',
#    'signal',
#    'signal',
#    'time,',
#    'routing']},
#  {'quoted': ['52186'],
#   'title': 'Thermal via planning for 3-D ICs.',
#   'authors': 'Jason Cong,Yan Zhang',
#   'date': '2005',
#   'source': 'ICCAD',
#   'index': '281991',
#   'abstract': ['one',
#    'challenges',
#    'One',
#    'effective',
#    'way',
#    'reducing',
#    'circuit',
#    'introduce',
#    'In',
#    'paper,',
#    'extended',
#    'planning',
#    'routing',
#    'framework',
#    'use',
#    'much',
#    'planning',
#    'algorithm.',
#    'We',
#    'problem',
#    'constraints',
#    'nonlinear',
#    'programming',
#    'problem',
#    'based',
#    'model',
#    'develop',
#    'efficient',
#    'heuristic',
#    'algorithm,',
#    'named',
#    'sequence',
#    'via',
#    'planning',
#    'The',
#    'via',
#    'distribution',
#    'convex',
#    'programming',
#    'problem,',
#    'via',
#    'planning',
#    'based',
#    'two',
#    'efficient',
#    'path',
#    'Experimental',
#    'results',
#    'show',
#    'algorithm',
#    'faster',
#    'direct',
#    'solution',
#    'via',
#    'planning',
#    'similar',
#    'solution',
#    'quality',
#    'However,',
#    'compared',
#    'recent',
#    'work',
#    'planning',
#    'algorithm',
#    'based',
#    'algorithm',
#    'reduce',
#    'total',
#    'number',
#    'required',
#    'similar']},
#  {'quoted': ['1078626'],
#   'title': 'Non-scan design-for-testability of RT-level data paths.',
#   'authors': 'Sujit Dey,Miodrag Potkonjak',
#   'date': '1994',
#   'source': 'ICCAD',
#   'index': '282051',
#   'abstract': ['This',
#    'paper',
#    'presents',
#    'technique',
#    'applicable',
#    'level',
#    'data',
#    'path',
#    'usually',
#    'due',
#    'presence',
#    'complex',
#    'loop',
#    'We',
#    'develop',
#    'new',
#    'structure',
#    'data',
#    'circuit',
#    'make',
#    'easily',
#    'without',
#    'either',
#    'scan',
#    'The',
#    'technique',
#    'applied',
#    'several',
#    'data',
#    'path',
#    'circuits.',
#    'Experimental',
#    'results',
#    'demonstrate',
#    'data',
#    'The',
#    'hardware',
#    'overhead',
#    'test',
#    'application',
#    'time',
#    'required',
#    'designs',
#    'significantly',
#    'lower',
#    'corresponding',
#    'partial',
#    'scan']},
#  ...]
